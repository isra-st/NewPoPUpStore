# %% [markdown]
# # New Opening PopUpStore

# %% [markdown]
# Check Connection to fotocasa

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
from getpass import getpass
from sqlalchemy import inspect
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import requests as r
import re
import geopy

# %%
url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'

# %%
r.get(url)

# %% [markdown]
# ## Flats for Rent

# %%
headers = """accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: es-ES,es;q=0.9,fr;q=0.8,en;q=0.7,pl;q=0.6
cache-control: no-cache
origin: https://www.fotocasa.es
pragma: no-cache
referer: https://www.fotocasa.es/
sec-ch-ua: "Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
resp = r.get(url, headers=headers)

# %%
resp

# %%
resp.json()

# %%
data = resp.json()

# %%
data.keys()

# %%
df_test = pd.json_normalize(data['realEstates'])

# %%
df_test

# %%
url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
resp = r.get(url, headers=headers)
data = resp.json()
df = pd.json_normalize(data['realEstates'])
number_of_iteration=0
time.sleep(2)
print('Page number: 1 scanned')

# %%
def get_df():
    url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
    resp = r.get(url, headers=headers)
    data = resp.json()
    df = pd.json_normalize(data['realEstates'])
    number_of_iteration=0
    time.sleep(2)
    for i in range(2,80):
        number_of_iteration+=1
        url = f'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber={i}&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
        resp = r.get(url, headers=headers)
        data = resp.json()
        df = df.append(pd.json_normalize(data['realEstates']))
        if number_of_iteration%10 and number_of_iteration:
            time.sleep(5)
        time.sleep(2)
        print(f'Page number: {i} scanned')
    df.to_json('df.json', orient='records')
    return df

# %%
#get_df()

# %%
df

# %%
import os

# %%
os.getcwd()

# %%
pd.read_json('Madrid_rent.json')

# %% [markdown]
# ## Flats for Sale

# %%
url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=1&propertyTypeId=2'

# %%
r.get(url)

# %%
headers = """accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: es-ES,es;q=0.9,fr;q=0.8,en;q=0.7,pl;q=0.6
cache-control: no-cache
origin: https://www.fotocasa.es
pragma: no-cache
referer: https://www.fotocasa.es/
sec-ch-ua: "Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
resp = r.get(url, headers=headers)

# %%
resp

# %%
resp.json()

# %%
data = resp.json()

# %%
data.keys()

# %%
df_test = pd.json_normalize(data['realEstates'])

# %%
len(df_test.columns)

# %%
def get_df():
    url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=1&propertyTypeId=2'
    resp = r.get(url, headers=headers)
    data = resp.json()
    df = pd.json_normalize(data['realEstates'])
    number_of_iteration=0
    time.sleep(2)
    for i in range(2,556):
        number_of_iteration+=1
        url = f'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber={i}&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=1&propertyTypeId=2'
        resp = r.get(url, headers=headers)
        data = resp.json()
        df = df.append(pd.json_normalize(data['realEstates']))
        if number_of_iteration%10 and number_of_iteration:
            time.sleep(5)
        time.sleep(2)
        print(f'Page number: {i} scanned')
    df.to_json('Madrid_sale.json', orient='records')
    return df

# %%
#get_df()

# %% [markdown]
# ## Start Cleanning

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
from getpass import getpass
from sqlalchemy import inspect
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import requests as r
import re
import geopy

# %%
sale = pd.read_json('Madrid_sale.orginal.json', orient='records')

# %%
sale

# %%
rent = pd.read_json('Madrid_rent.json', orient='records')

# %%
sale = pd.DataFrame(sale)

# %%
rent = pd.DataFrame(rent)

# %% [markdown]
# ## Duplicated - Sale

# %%
sale = sale.set_index(sale['id'])

# %%
len(sale)

# %%
sale = sale.drop_duplicates(subset=['id'])

# %%
len(sale)

# %% [markdown]
# ## Duplicated - Rent

# %%
rent = rent.set_index(rent['id'])

# %%
len(rent)

# %%
rent = rent.drop_duplicates(subset=['id'])

# %%
len(rent)

# %% [markdown]
# ## Cleaning Features column

# %%
sale.dtypes

# %%
sale.index

# %%
sale.shape

# %%
sale.size

# %%
sale.head()

# %%
pd.DataFrame(sale['features'])

# %%
features = pd.DataFrame(sale['features'])

# %%
features = features.apply(pd.Series)

# %%
features['features'].apply(pd.Series)

# %%
features = features['features'].apply(pd.Series)

# %%
#feats0 = features[0].apply(pd.Series)

# %%
feats0 = features[0].apply(pd.Series)
feats1 = features[1].apply(pd.Series)
feats2 = features[2].apply(pd.Series)
feats3 = features[3].apply(pd.Series)
feats4 = features[4].apply(pd.Series)
feats5 = features[5].apply(pd.Series)
feats6 = features[6].apply(pd.Series)
feats7 = features[7].apply(pd.Series)

# %%
feats0

# %%
feats.shape

# %%
feats.columns

# %%
#feats = feats.drop([0, 'maxValue', 'minValue'], axis=1)

# %%
feats0 = feats0.drop([0, 'maxValue', 'minValue'], axis=1)
feats1 = feats1.drop([0, 'maxValue', 'minValue'], axis=1)
feats2 = feats2.drop([0, 'maxValue', 'minValue'], axis=1)
feats3 = feats3.drop([0, 'maxValue', 'minValue'], axis=1)
feats4 = feats4.drop([0, 'maxValue', 'minValue'], axis=1)
feats5 = feats5.drop([0, 'maxValue', 'minValue'], axis=1)
feats6 = feats6.drop([0, 'maxValue', 'minValue'], axis=1)
feats7 = feats7.drop([0, 'maxValue', 'minValue'], axis=1)

# %%
feats0.shape

# %%
#feats['value'] = feats['value'].map(lambda x: str(x).strip('[]'))

# %%
feats0['value'] = feats0['value'].map(lambda x: str(x).strip('[]'))
feats1['value'] = feats1['value'].map(lambda x: str(x).strip('[]'))
feats2['value'] = feats2['value'].map(lambda x: str(x).strip('[]'))
feats3['value'] = feats3['value'].map(lambda x: str(x).strip('[]'))
feats4['value'] = feats4['value'].map(lambda x: str(x).strip('[]'))
feats5['value'] = feats5['value'].map(lambda x: str(x).strip('[]'))
feats6['value'] = feats6['value'].map(lambda x: str(x).strip('[]'))
feats7['value'] = feats7['value'].map(lambda x: str(x).strip('[]'))

# %%
feats

# %%
feats.shape

# %%
feats['value'].isna().sum()

# %%
# feats['value'] = feats['value'].astype('float')

# %%
feats0['value'] = feats0['value'].astype('float')
feats1['value'] = feats1['value'].astype('float')
feats2['value'] = feats2['value'].astype('float')
feats3['value'] = feats3['value'].astype('float')
feats4['value'] = feats4['value'].astype('float')
feats5['value'] = feats5['value'].astype('float')
feats6['value'] = feats6['value'].astype('float')
feats7['value'] = feats7['value'].astype('float')

# %%
#feats['value'] = feats['value'].fillna(value=0)

# %%
feats0['value'] = feats0['value'].fillna(value=0)
feats1['value'] = feats1['value'].fillna(value=0)
feats2['value'] = feats2['value'].fillna(value=0)
feats3['value'] = feats3['value'].fillna(value=0)
feats4['value'] = feats4['value'].fillna(value=0)
feats5['value'] = feats5['value'].fillna(value=0)
feats6['value'] = feats6['value'].fillna(value=0)
feats7['value'] = feats7['value'].fillna(value=0)

# %%
#feats['value'] = feats['value'].astype('int64')

# %%
feats0['value'] = feats0['value'].astype('int64')
feats1['value'] = feats1['value'].astype('int64')
feats2['value'] = feats2['value'].astype('int64')
feats3['value'] = feats3['value'].astype('int64')
feats4['value'] = feats4['value'].astype('int64')
feats5['value'] = feats5['value'].astype('int64')
feats6['value'] = feats6['value'].astype('int64')
feats7['value'] = feats7['value'].astype('int64')

# %%
feats.loc[(feats['value']<1)]

# %%
#feats.drop([158149988], inplace=True)

# %%
feats.shape

# %%
#feats = pd.pivot_table(feats, index=['id'], columns=feats['key'])

# %%
feats0 = pd.pivot_table(feats0, index=['id'], columns=feats0['key'])
feats1 = pd.pivot_table(feats1, index=['id'], columns=feats1['key'])
feats2 = pd.pivot_table(feats2, index=['id'], columns=feats2['key'])
feats3 = pd.pivot_table(feats3, index=['id'], columns=feats3['key'])
feats4 = pd.pivot_table(feats4, index=['id'], columns=feats4['key'])
feats5 = pd.pivot_table(feats5, index=['id'], columns=feats5['key'])
feats6 = pd.pivot_table(feats6, index=['id'], columns=feats6['key'])
feats7 = pd.pivot_table(feats7, index=['id'], columns=feats7['key'])

# %%
features_d = right5.add(right6, fill_value=0)

# %%
right1  right2 right 3 right4

# %%
sale

# %%
sale['bathrooms']=features_d.value['bathrooms']

# %%
sale['conservationState'] = features_d.value['conservationState']

# %%
sale['elevator'] = features_d.value['elevator']

# %%
sale['floor'] = features_d.value['floor']

# %%
sale['parking'] = features_d.value['parking']

# %%
sale['rooms'] = features_d.value['rooms']

# %%
sale['surface'] = features_d.value['surface']

# %%
sale['terrace'] = features_d.value['terrace']

# %%
sale.to_json('Madrid_sale.json', orient='records')

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %% [markdown]
# ## Droping some Columns isna()

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
from getpass import getpass
from sqlalchemy import inspect
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import requests as r
import re
import geopy

# %%
sale = pd.read_json('Madrid_salev1.json', orient='records')

# %%
sale.columns
# Out:
# Index(['id', 'multimedias', 'transactions', 'products', 'date', 'description',
#        'advertiser.logo.multimedia.typeId', 'detail.es', 'address.ubication',
#        'address.location.country', 'address.location.level1',
#        'address.location.level2', 'address.location.level3',
#        'address.location.level5', 'address.location.level7',
#        'address.location.level8', 'address.location.upperLevel',
#        'address.location.countryId', 'address.location.level1Id',
#        'address.location.level2Id', 'address.location.level3Id',
#        'address.location.level4Id', 'address.location.level5Id',
#        'address.location.level6Id', 'address.location.level7Id',
#        'address.location.level8Id', 'address.coordinates.accuracy',
#        'address.coordinates.latitude', 'address.coordinates.longitude',
#        'address.zipCode', 'bathrooms', 'conservationState', 'elevator',
#        'floor', 'parking', 'rooms', 'surface', 'terrace'],
#       dtype='object')

# %%
sale = sale.drop(['advertiser.phone', 'advertiser.typeId', 'advertiser.clientId','advertiser.urlAlias', 'advertiser.clientAlias','address.location.level4', 'address.location.level6','promotionId','typeId','subtypeId', 'isNew', 'isTop', 'isPhotoReport', 'isMsAdvance', 'isExternalContact','promotionId'], axis=1)

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %%
sale = sale.drop(['products', 'advertiser.logo.multimedia.typeId'], axis=1)

# %% [markdown]
# ## Lets attack multimedia column

# %%
sale
# Out:
#                   id                                        multimedias  \
# id
# 150476642  150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...              ...                                                ...
# 158823456  158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
#            transactions                    date  \
# id
# 150476642       2200000 2021-02-19 15:40:40.138
# 157313689        405000 2021-02-19 15:40:40.138
# 153519540       1930000 2021-02-19 15:40:40.138
# 154298390       1930000 2021-02-19 15:40:40.138
# 158184418        485000 2021-02-19 15:40:40.138
# ...                 ...                     ...
# 158823456        115000 2021-02-05 11:43:44.497
# 158823310        179000 2021-02-05 11:35:14.360
# 158823307        137000 2021-02-05 11:34:53.280
# 158823262        115000 2021-02-05 11:31:41.277
# 158823219        380000 2021-02-05 11:29:45.217
#
#                                                  description  \
# id
# 150476642  GILMAR Consulting Inmobiliario Madrid, Conde O...
# 157313689  Gilmar ofrece, magnifica Vivienda, Ubicada en ...
# 153519540  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 154298390  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 158184418  Magnifica vivienda en Ciudad Jardín, \r\n\r\nP...
# ...                                                      ...
# 158823456  Piso para actualizar en Zona Hellín.\r\n\r\nFa...
# 158823310  Magnífico dúplex loft a dos alturas, totalment...
# 158823307  Luminosa vivienda de 56 m2, amplio salón con c...
# 158823262  Fantástico Piso en zona Simancas, Impecable, t...
# 158823219  "Piso inteio, muy tranquilo en el corazón del ...
#
#                                                    detail.es  \
# id
# 150476642  /es/comprar/vivienda/madrid-capital/calefaccio...
# 157313689  /es/comprar/vivienda/madrid-capital/aire-acond...
# 153519540  /es/comprar/vivienda/madrid-capital/aire-acond...
# 154298390  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158184418  /es/comprar/vivienda/madrid-capital/calefaccio...
# ...                                                      ...
# 158823456  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823310  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823307  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823262  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823219  /es/comprar/vivienda/madrid-capital/aire-acond...
#
#                                            address.ubication  \
# id
# 150476642                               Andarrios, Hortaleza
# 157313689                                          Chamartín
# 153519540                                         Fuencarral
# 154298390                                         Fuencarral
# 158184418                                          Chamartín
# ...                                                      ...
# 158823456              Calle de Hinojosa del Duque, San Blas
# 158823310  Carretera de Vicálvaro a la Estac. O'donnell, ...
# 158823307                          Calle Garganchón, Barajas
# 158823262                         Calle de Zubieta, San Blas
# 158823219         Calle del Conde de Peñalver, 30, Salamanca
#
#           address.location.country address.location.level1  \
# id
# 150476642                   España                  Madrid
# 157313689                   España                  Madrid
# 153519540                   España                  Madrid
# 154298390                   España                  Madrid
# 158184418                   España                  Madrid
# ...                            ...                     ...
# 158823456                   España                  Madrid
# 158823310                   España                  Madrid
# 158823307                   España                  Madrid
# 158823262                   España                  Madrid
# 158823219                   España                  Madrid
#
#           address.location.level2  ... address.zipCode bathrooms  \
# id                                 ...
# 150476642                  Madrid  ...           28043       5.0
# 157313689                  Madrid  ...           28002       1.0
# 153519540                  Madrid  ...           28034       6.0
# 154298390                  Madrid  ...           28034       6.0
# 158184418                  Madrid  ...           28002       2.0
# ...                           ...  ...             ...       ...
# 158823456                  Madrid  ...           28037       1.0
# 158823310                  Madrid  ...           28032       2.0
# 158823307                  Madrid  ...           28042       1.0
# 158823262                  Madrid  ...           28037       1.0
# 158823219                  Madrid  ...           28006       1.0
#
#           conservationState elevator floor  parking  rooms  surface  terrace  \
# id
# 150476642               2.0      NaN   NaN      NaN    5.0    554.0      1.0
# 157313689               3.0      1.0   7.0      NaN    3.0     80.0      NaN
# 153519540               1.0      NaN   NaN      NaN    5.0    547.0      1.0
# 154298390               1.0      NaN   NaN      NaN    5.0    547.0      1.0
# 158184418               4.0      1.0   8.0      NaN    4.0    133.0      NaN
# ...                     ...      ...   ...      ...    ...      ...      ...
# 158823456               4.0      NaN   6.0      NaN    3.0     62.0      NaN
# 158823310               NaN      1.0   6.0      NaN    2.0     83.0      1.0
# 158823307               3.0      NaN   6.0      NaN    1.0     56.0      NaN
# 158823262               1.0      NaN   NaN      NaN    2.0     48.0      NaN
# 158823219               2.0      1.0   6.0      NaN    2.0     90.0      NaN
#
#                                                   multimedia
# id
# 150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...                                                      ...
# 158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
# [9280 rows x 37 columns]

# %%
sale = sale.set_index(sale['id'])

# %%
multimedia = pd.DataFrame(sale['multimedias'])

# %%
sale['multimedia']=multimedia['multimedias']

# %% [markdown]
# Let's go for the price of the flat

# %%
price = pd.DataFrame(sale['transactions'])

# %%
price = price['transactions'].apply(pd.Series)

# %%
price = price[0].apply(pd.Series)

# %%
price['value'] = price['value'].map(lambda x: str(x).strip('[]'))

# %%
price['value'] = price['value'].astype('int64')

# %%
sale['transactions'] = price['value']

# %%
# Out:
#                   id                                        multimedias  \
# id
# 150476642  150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...              ...                                                ...
# 158823456  158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
#            transactions                  products                    date  \
# id
# 150476642       2200000              [{'id': 56}] 2021-02-19 15:40:40.138
# 157313689        405000              [{'id': 56}] 2021-02-19 15:40:40.138
# 153519540       1930000   [{'id': 3}, {'id': 56}] 2021-02-19 15:40:40.138
# 154298390       1930000              [{'id': 56}] 2021-02-19 15:40:40.138
# 158184418        485000              [{'id': 56}] 2021-02-19 15:40:40.138
# ...                 ...                       ...                     ...
# 158823456        115000              [{'id': 62}] 2021-02-05 11:43:44.497
# 158823310        179000  [{'id': 62}, {'id': 56}] 2021-02-05 11:35:14.360
# 158823307        137000                        [] 2021-02-05 11:34:53.280
# 158823262        115000              [{'id': 62}] 2021-02-05 11:31:41.277
# 158823219        380000               [{'id': 3}] 2021-02-05 11:29:45.217
#
#                                                  description  \
# id
# 150476642  GILMAR Consulting Inmobiliario Madrid, Conde O...
# 157313689  Gilmar ofrece, magnifica Vivienda, Ubicada en ...
# 153519540  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 154298390  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 158184418  Magnifica vivienda en Ciudad Jardín, \r\n\r\nP...
# ...                                                      ...
# 158823456  Piso para actualizar en Zona Hellín.\r\n\r\nFa...
# 158823310  Magnífico dúplex loft a dos alturas, totalment...
# 158823307  Luminosa vivienda de 56 m2, amplio salón con c...
# 158823262  Fantástico Piso en zona Simancas, Impecable, t...
# 158823219  "Piso inteio, muy tranquilo en el corazón del ...
#
#            advertiser.logo.multimedia.typeId  \
# id
# 150476642                                8.0
# 157313689                                8.0
# 153519540                                8.0
# 154298390                                8.0
# 158184418                                8.0
# ...                                      ...
# 158823456                                8.0
# 158823310                                8.0
# 158823307                                8.0
# 158823262                                8.0
# 158823219                                NaN
#
#                                                    detail.es  \
# id
# 150476642  /es/comprar/vivienda/madrid-capital/calefaccio...
# 157313689  /es/comprar/vivienda/madrid-capital/aire-acond...
# 153519540  /es/comprar/vivienda/madrid-capital/aire-acond...
# 154298390  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158184418  /es/comprar/vivienda/madrid-capital/calefaccio...
# ...                                                      ...
# 158823456  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823310  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823307  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823262  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823219  /es/comprar/vivienda/madrid-capital/aire-acond...
#
#                                            address.ubication  \
# id
# 150476642                               Andarrios, Hortaleza
# 157313689                                          Chamartín
# 153519540                                         Fuencarral
# 154298390                                         Fuencarral
# 158184418                                          Chamartín
# ...                                                      ...
# 158823456              Calle de Hinojosa del Duque, San Blas
# 158823310  Carretera de Vicálvaro a la Estac. O'donnell, ...
# 158823307                          Calle Garganchón, Barajas
# 158823262                         Calle de Zubieta, San Blas
# 158823219         Calle del Conde de Peñalver, 30, Salamanca
#
#           address.location.country  ... address.zipCode bathrooms  \
# id                                  ...
# 150476642                   España  ...           28043       5.0
# 157313689                   España  ...           28002       1.0
# 153519540                   España  ...           28034       6.0
# 154298390                   España  ...           28034       6.0
# 158184418                   España  ...           28002       2.0
# ...                            ...  ...             ...       ...
# 158823456                   España  ...           28037       1.0
# 158823310                   España  ...           28032       2.0
# 158823307                   España  ...           28042       1.0
# 158823262                   España  ...           28037       1.0
# 158823219                   España  ...           28006       1.0
#
#           conservationState elevator floor parking rooms  surface  terrace  \
# id
# 150476642               2.0      NaN   NaN     NaN   5.0    554.0      1.0
# 157313689               3.0      1.0   7.0     NaN   3.0     80.0      NaN
# 153519540               1.0      NaN   NaN     NaN   5.0    547.0      1.0
# 154298390               1.0      NaN   NaN     NaN   5.0    547.0      1.0
# 158184418               4.0      1.0   8.0     NaN   4.0    133.0      NaN
# ...                     ...      ...   ...     ...   ...      ...      ...
# 158823456               4.0      NaN   6.0     NaN   3.0     62.0      NaN
# 158823310               NaN      1.0   6.0     NaN   2.0     83.0      1.0
# 158823307               3.0      NaN   6.0     NaN   1.0     56.0      NaN
# 158823262               1.0      NaN   NaN     NaN   2.0     48.0      NaN
# 158823219               2.0      1.0   6.0     NaN   2.0     90.0      NaN
#
#                                                   multimedia
# id
# 150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...                                                      ...
# 158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
# [9280 rows x 39 columns]

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %%
sale.rename(columns={'transactions':'price'}, inplace=True)

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %%
sale
# Out:
#                   id                                        multimedias  \
# id
# 150476642  150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...              ...                                                ...
# 158823456  158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
#              price                    date  \
# id
# 150476642  2200000 2021-02-19 15:40:40.138
# 157313689   405000 2021-02-19 15:40:40.138
# 153519540  1930000 2021-02-19 15:40:40.138
# 154298390  1930000 2021-02-19 15:40:40.138
# 158184418   485000 2021-02-19 15:40:40.138
# ...            ...                     ...
# 158823456   115000 2021-02-05 11:43:44.497
# 158823310   179000 2021-02-05 11:35:14.360
# 158823307   137000 2021-02-05 11:34:53.280
# 158823262   115000 2021-02-05 11:31:41.277
# 158823219   380000 2021-02-05 11:29:45.217
#
#                                                  description  \
# id
# 150476642  GILMAR Consulting Inmobiliario Madrid, Conde O...
# 157313689  Gilmar ofrece, magnifica Vivienda, Ubicada en ...
# 153519540  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 154298390  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 158184418  Magnifica vivienda en Ciudad Jardín, \r\n\r\nP...
# ...                                                      ...
# 158823456  Piso para actualizar en Zona Hellín.\r\n\r\nFa...
# 158823310  Magnífico dúplex loft a dos alturas, totalment...
# 158823307  Luminosa vivienda de 56 m2, amplio salón con c...
# 158823262  Fantástico Piso en zona Simancas, Impecable, t...
# 158823219  "Piso inteio, muy tranquilo en el corazón del ...
#
#                                                    detail.es  \
# id
# 150476642  /es/comprar/vivienda/madrid-capital/calefaccio...
# 157313689  /es/comprar/vivienda/madrid-capital/aire-acond...
# 153519540  /es/comprar/vivienda/madrid-capital/aire-acond...
# 154298390  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158184418  /es/comprar/vivienda/madrid-capital/calefaccio...
# ...                                                      ...
# 158823456  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823310  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823307  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823262  /es/comprar/vivienda/madrid-capital/aire-acond...
# 158823219  /es/comprar/vivienda/madrid-capital/aire-acond...
#
#                                            address.ubication  \
# id
# 150476642                               Andarrios, Hortaleza
# 157313689                                          Chamartín
# 153519540                                         Fuencarral
# 154298390                                         Fuencarral
# 158184418                                          Chamartín
# ...                                                      ...
# 158823456              Calle de Hinojosa del Duque, San Blas
# 158823310  Carretera de Vicálvaro a la Estac. O'donnell, ...
# 158823307                          Calle Garganchón, Barajas
# 158823262                         Calle de Zubieta, San Blas
# 158823219         Calle del Conde de Peñalver, 30, Salamanca
#
#           address.location.country address.location.level1  \
# id
# 150476642                   España                  Madrid
# 157313689                   España                  Madrid
# 153519540                   España                  Madrid
# 154298390                   España                  Madrid
# 158184418                   España                  Madrid
# ...                            ...                     ...
# 158823456                   España                  Madrid
# 158823310                   España                  Madrid
# 158823307                   España                  Madrid
# 158823262                   España                  Madrid
# 158823219                   España                  Madrid
#
#           address.location.level2  ... address.zipCode bathrooms  \
# id                                 ...
# 150476642                  Madrid  ...           28043       5.0
# 157313689                  Madrid  ...           28002       1.0
# 153519540                  Madrid  ...           28034       6.0
# 154298390                  Madrid  ...           28034       6.0
# 158184418                  Madrid  ...           28002       2.0
# ...                           ...  ...             ...       ...
# 158823456                  Madrid  ...           28037       1.0
# 158823310                  Madrid  ...           28032       2.0
# 158823307                  Madrid  ...           28042       1.0
# 158823262                  Madrid  ...           28037       1.0
# 158823219                  Madrid  ...           28006       1.0
#
#           conservationState elevator floor  parking  rooms  surface  terrace  \
# id
# 150476642               2.0      NaN   NaN      NaN    5.0    554.0      1.0
# 157313689               3.0      1.0   7.0      NaN    3.0     80.0      NaN
# 153519540               1.0      NaN   NaN      NaN    5.0    547.0      1.0
# 154298390               1.0      NaN   NaN      NaN    5.0    547.0      1.0
# 158184418               4.0      1.0   8.0      NaN    4.0    133.0      NaN
# ...                     ...      ...   ...      ...    ...      ...      ...
# 158823456               4.0      NaN   6.0      NaN    3.0     62.0      NaN
# 158823310               NaN      1.0   6.0      NaN    2.0     83.0      1.0
# 158823307               3.0      NaN   6.0      NaN    1.0     56.0      NaN
# 158823262               1.0      NaN   NaN      NaN    2.0     48.0      NaN
# 158823219               2.0      1.0   6.0      NaN    2.0     90.0      NaN
#
#                                                   multimedia
# id
# 150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...                                                      ...
# 158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
# [9280 rows x 37 columns]

# %% [markdown]
# ## Column - Detail.es

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %%
price['value'] = price['value'].map(lambda x: str(x).strip('[]'))

# %%
sale['detail.es'] = sale['detail.es'].map(lambda x: x.strip('/es/comprar/vivienda/madrid-capital/'))

# %%
sale
# Out:
#                   id                                        multimedias  \
# id
# 150476642  150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...              ...                                                ...
# 158823456  158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
#              price                    date  \
# id
# 150476642  2200000 2021-02-19 15:40:40.138
# 157313689   405000 2021-02-19 15:40:40.138
# 153519540  1930000 2021-02-19 15:40:40.138
# 154298390  1930000 2021-02-19 15:40:40.138
# 158184418   485000 2021-02-19 15:40:40.138
# ...            ...                     ...
# 158823456   115000 2021-02-05 11:43:44.497
# 158823310   179000 2021-02-05 11:35:14.360
# 158823307   137000 2021-02-05 11:34:53.280
# 158823262   115000 2021-02-05 11:31:41.277
# 158823219   380000 2021-02-05 11:29:45.217
#
#                                                  description  \
# id
# 150476642  GILMAR Consulting Inmobiliario Madrid, Conde O...
# 157313689  Gilmar ofrece, magnifica Vivienda, Ubicada en ...
# 153519540  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 154298390  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 158184418  Magnifica vivienda en Ciudad Jardín, \r\n\r\nP...
# ...                                                      ...
# 158823456  Piso para actualizar en Zona Hellín.\r\n\r\nFa...
# 158823310  Magnífico dúplex loft a dos alturas, totalment...
# 158823307  Luminosa vivienda de 56 m2, amplio salón con c...
# 158823262  Fantástico Piso en zona Simancas, Impecable, t...
# 158823219  "Piso inteio, muy tranquilo en el corazón del ...
#
#                                                    detail.es  \
# id
# 150476642  faccion-jardin-terraza-trastero-patio-piscina/...
# 157313689                 faccion-parking-ascensor/157313689
# 153519540     king-jardin-terraza-trastero-piscina/153519540
# 154298390     king-jardin-terraza-trastero-piscina/154298390
# 158184418                         faccion-ascensor/158184418
# ...                                                      ...
# 158823456                                  faccion/158823456
# 158823310  faccion-parking-terraza-ascensor-amueblado/158...
# 158823307                        faccion-amueblado/158823307
# 158823262                     faccion-no-amueblado/158823262
# 158823219         faccion-ascensor-patio-amueblado/158823219
#
#                                            address.ubication  \
# id
# 150476642                               Andarrios, Hortaleza
# 157313689                                          Chamartín
# 153519540                                         Fuencarral
# 154298390                                         Fuencarral
# 158184418                                          Chamartín
# ...                                                      ...
# 158823456              Calle de Hinojosa del Duque, San Blas
# 158823310  Carretera de Vicálvaro a la Estac. O'donnell, ...
# 158823307                          Calle Garganchón, Barajas
# 158823262                         Calle de Zubieta, San Blas
# 158823219         Calle del Conde de Peñalver, 30, Salamanca
#
#           address.location.country address.location.level1  \
# id
# 150476642                   España                  Madrid
# 157313689                   España                  Madrid
# 153519540                   España                  Madrid
# 154298390                   España                  Madrid
# 158184418                   España                  Madrid
# ...                            ...                     ...
# 158823456                   España                  Madrid
# 158823310                   España                  Madrid
# 158823307                   España                  Madrid
# 158823262                   España                  Madrid
# 158823219                   España                  Madrid
#
#           address.location.level2  ... address.zipCode bathrooms  \
# id                                 ...
# 150476642                  Madrid  ...           28043       5.0
# 157313689                  Madrid  ...           28002       1.0
# 153519540                  Madrid  ...           28034       6.0
# 154298390                  Madrid  ...           28034       6.0
# 158184418                  Madrid  ...           28002       2.0
# ...                           ...  ...             ...       ...
# 158823456                  Madrid  ...           28037       1.0
# 158823310                  Madrid  ...           28032       2.0
# 158823307                  Madrid  ...           28042       1.0
# 158823262                  Madrid  ...           28037       1.0
# 158823219                  Madrid  ...           28006       1.0
#
#           conservationState elevator floor  parking  rooms  surface  terrace  \
# id
# 150476642               2.0      NaN   NaN      NaN    5.0    554.0      1.0
# 157313689               3.0      1.0   7.0      NaN    3.0     80.0      NaN
# 153519540               1.0      NaN   NaN      NaN    5.0    547.0      1.0
# 154298390               1.0      NaN   NaN      NaN    5.0    547.0      1.0
# 158184418               4.0      1.0   8.0      NaN    4.0    133.0      NaN
# ...                     ...      ...   ...      ...    ...      ...      ...
# 158823456               4.0      NaN   6.0      NaN    3.0     62.0      NaN
# 158823310               NaN      1.0   6.0      NaN    2.0     83.0      1.0
# 158823307               3.0      NaN   6.0      NaN    1.0     56.0      NaN
# 158823262               1.0      NaN   NaN      NaN    2.0     48.0      NaN
# 158823219               2.0      1.0   6.0      NaN    2.0     90.0      NaN
#
#                                                   multimedia
# id
# 150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...                                                      ...
# 158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
# [9280 rows x 37 columns]

# %%
sale = sale.drop(['multimedias'], axis=1)

# %%
sale = sale.drop(['address.location.level2'], axis=1)

# %%
zona = sale['address.location.level3'].apply(pd.Series)

# %%
sale = sale.drop(['address.location.level8Id'], axis=1)

# %%
sale.columns
# Out:
# Index(['id', 'price', 'date', 'customer_description', 'short_detail',
#        'address', 'country', 'neighborhood', 'district',
#        'address.location.level5Id', 'address.location.level7Id',
#        'address.location.level8Id', 'address.coordinates.accuracy',
#        'address.coordinates.latitude', 'address.coordinates.longitude',
#        'address.zipCode', 'bathrooms', 'conservationState', 'elevator',
#        'floor', 'parking', 'rooms', 'surface', 'terrace', 'multimedia'],
#       dtype='object')

# %%
cols = ['id', 'price', 'publish_date', 'customer_description', 'short_detail',
       'address', 'country', 'neighborhood', 'district',
       'coordinates.accuracy', 'coordinates.latitude',
       'coordinates.longitude', 'zipCode', 'bathrooms', 'conservationState',
       'elevator', 'floor', 'parking', 'rooms', 'surface', 'terrace',
       'multimedia']

# %%
sale.columns
# Out:
# Index(['id', 'price', 'date', 'customer_description', 'short_detail',
#        'address', 'country', 'neighborhood', 'district',
#        'address.coordinates.accuracy', 'coordinates.latitude',
#        'coordinates.longitude', 'zipCode', 'bathrooms', 'conservationState',
#        'elevator', 'floor', 'parking', 'rooms', 'surface', 'terrace',
#        'multimedia'],
#       dtype='object')

# %%
sale
# Out:
#                   id    price                    date  \
# id
# 150476642  150476642  2200000 2021-02-19 15:40:40.138
# 157313689  157313689   405000 2021-02-19 15:40:40.138
# 153519540  153519540  1930000 2021-02-19 15:40:40.138
# 154298390  154298390  1930000 2021-02-19 15:40:40.138
# 158184418  158184418   485000 2021-02-19 15:40:40.138
# ...              ...      ...                     ...
# 158823456  158823456   115000 2021-02-05 11:43:44.497
# 158823310  158823310   179000 2021-02-05 11:35:14.360
# 158823307  158823307   137000 2021-02-05 11:34:53.280
# 158823262  158823262   115000 2021-02-05 11:31:41.277
# 158823219  158823219   380000 2021-02-05 11:29:45.217
#
#                                         customer_description  \
# id
# 150476642  GILMAR Consulting Inmobiliario Madrid, Conde O...
# 157313689  Gilmar ofrece, magnifica Vivienda, Ubicada en ...
# 153519540  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 154298390  Gilmar Mirasierra - Puerta de Hierro (91771777...
# 158184418  Magnifica vivienda en Ciudad Jardín, \r\n\r\nP...
# ...                                                      ...
# 158823456  Piso para actualizar en Zona Hellín.\r\n\r\nFa...
# 158823310  Magnífico dúplex loft a dos alturas, totalment...
# 158823307  Luminosa vivienda de 56 m2, amplio salón con c...
# 158823262  Fantástico Piso en zona Simancas, Impecable, t...
# 158823219  "Piso inteio, muy tranquilo en el corazón del ...
#
#                                                 short_detail  \
# id
# 150476642  faccion-jardin-terraza-trastero-patio-piscina/...
# 157313689                 faccion-parking-ascensor/157313689
# 153519540     king-jardin-terraza-trastero-piscina/153519540
# 154298390     king-jardin-terraza-trastero-piscina/154298390
# 158184418                         faccion-ascensor/158184418
# ...                                                      ...
# 158823456                                  faccion/158823456
# 158823310  faccion-parking-terraza-ascensor-amueblado/158...
# 158823307                        faccion-amueblado/158823307
# 158823262                     faccion-no-amueblado/158823262
# 158823219         faccion-ascensor-patio-amueblado/158823219
#
#                                                      address country  \
# id
# 150476642                               Andarrios, Hortaleza  España
# 157313689                                          Chamartín  España
# 153519540                                         Fuencarral  España
# 154298390                                         Fuencarral  España
# 158184418                                          Chamartín  España
# ...                                                      ...     ...
# 158823456              Calle de Hinojosa del Duque, San Blas  España
# 158823310  Carretera de Vicálvaro a la Estac. O'donnell, ...  España
# 158823307                          Calle Garganchón, Barajas  España
# 158823262                         Calle de Zubieta, San Blas  España
# 158823219         Calle del Conde de Peñalver, 30, Salamanca  España
#
#           neighborhood                district  address.coordinates.accuracy  \
# id
# 150476642    Hortaleza   Conde Orgaz - Piovera                             0
# 157313689    Chamartín             Prosperidad                             0
# 153519540   Fuencarral  Tres Olivos - Valverde                             0
# 154298390   Fuencarral  Tres Olivos - Valverde                             0
# 158184418    Chamartín           Ciudad Jardín                             0
# ...                ...                     ...                           ...
# 158823456     San Blas                  Hellín                             0
# 158823310     San Blas           Rosas - Musas                             0
# 158823307      Barajas              Aeropuerto                             0
# 158823262     San Blas                Simancas                             0
# 158823219    Salamanca                    Goya                             1
#
#            ...  zipCode  bathrooms conservationState  elevator  floor  \
# id         ...
# 150476642  ...    28043        5.0               2.0       NaN    NaN
# 157313689  ...    28002        1.0               3.0       1.0    7.0
# 153519540  ...    28034        6.0               1.0       NaN    NaN
# 154298390  ...    28034        6.0               1.0       NaN    NaN
# 158184418  ...    28002        2.0               4.0       1.0    8.0
# ...        ...      ...        ...               ...       ...    ...
# 158823456  ...    28037        1.0               4.0       NaN    6.0
# 158823310  ...    28032        2.0               NaN       1.0    6.0
# 158823307  ...    28042        1.0               3.0       NaN    6.0
# 158823262  ...    28037        1.0               1.0       NaN    NaN
# 158823219  ...    28006        1.0               2.0       1.0    6.0
#
#            parking  rooms  surface  terrace  \
# id
# 150476642      NaN    5.0    554.0      1.0
# 157313689      NaN    3.0     80.0      NaN
# 153519540      NaN    5.0    547.0      1.0
# 154298390      NaN    5.0    547.0      1.0
# 158184418      NaN    4.0    133.0      NaN
# ...            ...    ...      ...      ...
# 158823456      NaN    3.0     62.0      NaN
# 158823310      NaN    2.0     83.0      1.0
# 158823307      NaN    1.0     56.0      NaN
# 158823262      NaN    2.0     48.0      NaN
# 158823219      NaN    2.0     90.0      NaN
#
#                                                   multimedia
# id
# 150476642  [{'url': 'https://d.inmofactory.com/1/100202/1...
# 157313689  [{'url': 'https://my.matterport.com/show/?m=fi...
# 153519540  [{'url': 'https://d.inmofactory.com/1/100207/1...
# 154298390  [{'url': 'https://images.inmofactory.com/inmof...
# 158184418  [{'url': 'https://d.inmofactory.com/1/89548/26...
# ...                                                      ...
# 158823456  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823310  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823307  [{'url': 'https://d.inmofactory.com/1/98925/27...
# 158823262  [{'url': 'https://d.inmofactory.com/1/85276/27...
# 158823219  [{'url': 'https://d.inmofactory.com/1/88669/27...
#
# [9280 rows x 22 columns]

# %%
sale['address.coordinates.accuracy']
# Out:
# (9280,)

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %% [markdown]
# ## New_Column Price m2

# %%
sale['Price_m2'] = round(sale['price']/sale['surface'], 0)

# %%
sale.Price_m2.colanme

# %%
sale.rename(columns={'Price_m2':'price_m2'}, inplace=True)

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9280 entries, 150476642 to 158823219
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            9280 non-null   int64
#  1   price                         9280 non-null   int64
#  2   date                          9280 non-null   datetime64[ns]
#  3   customer_description          9233 non-null   object
#  4   short_detail                  9280 non-null   object
#  5   address                       9280 non-null   object
#  6   country                       9280 non-null   object
#  7   neighborhood                  9280 non-null   object
#  8   district                      9280 non-null   object
#  9   address.coordinates.accuracy  9280 non-null   int64
#  10  coordinates.latitude          9280 non-null   float64
#  11  coordinates.longitude         9280 non-null   float64
#  12  zipCode                       9280 non-null   object
#  13  bathrooms                     9134 non-null   float64
#  14  conservationState             4820 non-null   float64
#  15  elevator                      5632 non-null   float64
#  16  floor                         6507 non-null   float64
#  17  parking                       887 non-null    float64
#  18  rooms                         8995 non-null   float64
#  19  surface                       9257 non-null   float64
#  20  terrace                       3181 non-null   float64
#  21  multimedia                    9280 non-null   object
#  22  price_m2                      9257 non-null   float64
# dtypes: datetime64[ns](1), float64(11), int64(3), object(8)
# memory usage: 2.0+ MB

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %%
sale['customer_description'] = sale['customer_description'].apply(lambda x : str(x).strip('\r\n\r\n'))

# %%
sale['customer_description'].values[1]
# Out:
# 'Gilmar ofrece, magnifica Vivienda, Ubicada en Prosperidad, zona norte de Madrid. Piso exterior, con una superficie construida de 80 m2 catastrales, 71 m2 útiles, distribuidos en: Hall de entrada espacioso, 3 buenos Dormitorios, 1 Cuarto de baño completo, salón-comedor, cocina independiente y equipada. Dispone de Calefacción Central, suelos de Tarima. 4 armarios empotrados, puerta de seguridad.\r\n\r\nLa finca dispone de portero físico, acceso a personas con movilidad reducida.\r\n\r\nEl barrio ya consolidado y excelentemente comunicado cuenta con zonas deportivas, colegios, iglesias, guarderías, gran oferta de restaurantes, terrazas, pequeño comercio y supermercados, así como parques y amplias zonas verdes. Con acceso directo a la M-30, que comunica tanto al resto de la red arterial como al aeropuerto, Igualmente cercano se encuentra el intercambiador de autobuses de la Avda. de América y las líneas de autobuses de la EMT números: 9, 40, 72, 73, 120,43 y cercana la estación de metro Alfonso XIII."\r\n\r\nComercializa Consulting Inmobiliario Gilmar Avenida America 91 771 77 99.\r\n\r\nEl Barrio de Prosperidad, Chamartín es una de las zonas más demandadas del distrito por su gran ambiente familiar y multitud de servicios, sin abandonar el entorno de zonas verdes por el que se caracteriza este distinguido distrito. Chamartín. Dispone de una gran variedad de zonas de ocio como el Auditorio Nacional de Música o el Parque de Berlín. Las necesidades básicas familiares, están totalmente cubiertas por diversidad de comercios, tiendas tradicionales, galerías comerciales con los productos más frescos e incluso famosos supermercados de grandes superficies. La arquitectura por la que se rodea la zona ronda desde edificios clásicos hasta algunos de los edificios más modernos de la capital como el IBM o el Hotel Silken Puerta de América. \r\n\r\nLa zona es conocida también por sus centros educativos. Colegios públicos dentro de los mejores catalogados, así como gran variedad de colegios privados bilingües y de gran relevancia. Todo, sin olvidarse de universidades tan conocidas como la escuela universitaria de diseño, innovación y tecnología ESNE.\r\n\r\nExiste también en la zona, el polideportivo municipal “El Pradillo”, para practicar todo tipo de deportes, en cualquier época del año.\r\n\r\nLa red de transporte público de la zona garantiza gran comodidad al contar con las paradas de metro de Prosperidad, Cartagena, Alfonso XIII y a un paseo del intercambiador de Avenida de América que cuenta con multitud de conexiones con líneas de autobús (40,43,72,9) Asimismo, dispone de un rápido acceso a algunas de las carreteras más destacadas de Madrid como la M30 y A2, que le conducirán en pocos minutos al aeropuerto.'

# %%
sale.to_json('Madrid_salev1.json', orient='records')

# %% [markdown]
# ## To SQL >>>>

# %%
sale = pd.read_json('Madrid_salev1.json', orient='records')

# %%
sale
# Out:
#              id    price                    date  \
# 0     150476642  2200000 2021-02-19 15:40:40.138
# 1     157313689   405000 2021-02-19 15:40:40.138
# 2     153519540  1930000 2021-02-19 15:40:40.138
# 3     154298390  1930000 2021-02-19 15:40:40.138
# 4     158184418   485000 2021-02-19 15:40:40.138
# ...         ...      ...                     ...
# 9275  158823456   115000 2021-02-05 11:43:44.497
# 9276  158823310   179000 2021-02-05 11:35:14.360
# 9277  158823307   137000 2021-02-05 11:34:53.280
# 9278  158823262   115000 2021-02-05 11:31:41.277
# 9279  158823219   380000 2021-02-05 11:29:45.217
#
#                                    customer_description  \
# 0     GILMAR Consulting Inmobiliario Madrid, Conde O...
# 1     Gilmar ofrece, magnifica Vivienda, Ubicada en ...
# 2     Gilmar Mirasierra - Puerta de Hierro (91771777...
# 3     Gilmar Mirasierra - Puerta de Hierro (91771777...
# 4     Magnifica vivienda en Ciudad Jardín, \r\n\r\nP...
# ...                                                 ...
# 9275  Piso para actualizar en Zona Hellín.\r\n\r\nFa...
# 9276  Magnífico dúplex loft a dos alturas, totalment...
# 9277  Luminosa vivienda de 56 m2, amplio salón con c...
# 9278  Fantástico Piso en zona Simancas, Impecable, t...
# 9279  "Piso inteio, muy tranquilo en el corazón del ...
#
#                                            short_detail  \
# 0     faccion-jardin-terraza-trastero-patio-piscina/...
# 1                    faccion-parking-ascensor/157313689
# 2        king-jardin-terraza-trastero-piscina/153519540
# 3        king-jardin-terraza-trastero-piscina/154298390
# 4                            faccion-ascensor/158184418
# ...                                                 ...
# 9275                                  faccion/158823456
# 9276  faccion-parking-terraza-ascensor-amueblado/158...
# 9277                        faccion-amueblado/158823307
# 9278                     faccion-no-amueblado/158823262
# 9279         faccion-ascensor-patio-amueblado/158823219
#
#                                                 address country neighborhood  \
# 0                                  Andarrios, Hortaleza  España    Hortaleza
# 1                                             Chamartín  España    Chamartín
# 2                                            Fuencarral  España   Fuencarral
# 3                                            Fuencarral  España   Fuencarral
# 4                                             Chamartín  España    Chamartín
# ...                                                 ...     ...          ...
# 9275              Calle de Hinojosa del Duque, San Blas  España     San Blas
# 9276  Carretera de Vicálvaro a la Estac. O'donnell, ...  España     San Blas
# 9277                          Calle Garganchón, Barajas  España      Barajas
# 9278                         Calle de Zubieta, San Blas  España     San Blas
# 9279         Calle del Conde de Peñalver, 30, Salamanca  España    Salamanca
#
#                     district  address.coordinates.accuracy  ...  bathrooms  \
# 0      Conde Orgaz - Piovera                             0  ...        5.0
# 1                Prosperidad                             0  ...        1.0
# 2     Tres Olivos - Valverde                             0  ...        6.0
# 3     Tres Olivos - Valverde                             0  ...        6.0
# 4              Ciudad Jardín                             0  ...        2.0
# ...                      ...                           ...  ...        ...
# 9275                  Hellín                             0  ...        1.0
# 9276           Rosas - Musas                             0  ...        2.0
# 9277              Aeropuerto                             0  ...        1.0
# 9278                Simancas                             0  ...        1.0
# 9279                    Goya                             1  ...        1.0
#
#       conservationState elevator  floor  parking  rooms  surface  terrace  \
# 0                   2.0      NaN    NaN      NaN    5.0    554.0      1.0
# 1                   3.0      1.0    7.0      NaN    3.0     80.0      NaN
# 2                   1.0      NaN    NaN      NaN    5.0    547.0      1.0
# 3                   1.0      NaN    NaN      NaN    5.0    547.0      1.0
# 4                   4.0      1.0    8.0      NaN    4.0    133.0      NaN
# ...                 ...      ...    ...      ...    ...      ...      ...
# 9275                4.0      NaN    6.0      NaN    3.0     62.0      NaN
# 9276                NaN      1.0    6.0      NaN    2.0     83.0      1.0
# 9277                3.0      NaN    6.0      NaN    1.0     56.0      NaN
# 9278                1.0      NaN    NaN      NaN    2.0     48.0      NaN
# 9279                2.0      1.0    6.0      NaN    2.0     90.0      NaN
#
#                                              multimedia  price_m2
# 0     [{'url': 'https://d.inmofactory.com/1/100202/1...    3971.0
# 1     [{'url': 'https://my.matterport.com/show/?m=fi...    5062.0
# 2     [{'url': 'https://d.inmofactory.com/1/100207/1...    3528.0
# 3     [{'url': 'https://images.inmofactory.com/inmof...    3528.0
# 4     [{'url': 'https://d.inmofactory.com/1/89548/26...    3647.0
# ...                                                 ...       ...
# 9275  [{'url': 'https://d.inmofactory.com/1/85276/27...    1855.0
# 9276  [{'url': 'https://d.inmofactory.com/1/85276/27...    2157.0
# 9277  [{'url': 'https://d.inmofactory.com/1/98925/27...    2446.0
# 9278  [{'url': 'https://d.inmofactory.com/1/85276/27...    2396.0
# 9279  [{'url': 'https://d.inmofactory.com/1/88669/27...    4222.0
#
# [9280 rows x 23 columns]

# %%
sale.to_csv('Madrid_salev1.csv', index=False)

# %%
username='root'
password='password'
server='localhost'
database='madrid'
password=getpass()
engine = create_engine(f'mysql+pymysql://{username}:{password}@{server}/{database}')
# Out:
# ········

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# []

# %%
for_sale = pd.read_csv('Madrid_salev1.csv')

# %% [markdown]
# ### Import table to SQL Madrid Schema

# %%
for_sale.to_sql('sale', con=engine,index=False,if_exists='append')

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['sale']
