# %% [markdown]
# # New Opening PopUpStore

# %% [markdown]
# ## Check Connection to Idealista

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
from getpass import getpass
from sqlalchemy import inspect
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import requests as r
import re
import geopy

# %%
url = 'https://www.idealista.com/'

# %%
r.get(url)
# Out:
# <Response [403]>

# %%
headers = """accept: text/plain, */*; q=0.01
accept-encoding: gzip, deflate, br
accept-language: es-ES,es;q=0.9,fr;q=0.8,en;q=0.7,pl;q=0.6
cache-control: no-cache
origin: https://www.idealista.com
pragma: no-cache
referer: https://www.idealista.com/
sec-ch-ua: "Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
r.get(url, headers=headers)
# Out:
# <Response [403]>

# %%
resp=r.get(url, headers=headers)

# %% [markdown]
# ## Reting Flats Madrid

# %% [markdown]
# ### #Card: 1 - Get Announce ID

# %%
url = "https://www.idealista.com/alquiler-viviendas/madrid-madrid/pagina-1.htm"

# %% [markdown]
# The Announce ID must be like: 92909170

# %%
soup = BeautifulSoup(resp. content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-userauth="false" env="es" lang="es" username="">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Casas y pisos en alquiler en Madrid — idealista</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Alquiler casas y pisos en Madrid, a partir de 335 euros de particulares e inmobiliarias. Alquiler casas y pisos en Madrid: anuncios de particular a particular y de agencias inmobiliarias." name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <script src="https://st1.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-consent-lang.js"></script>
# ...

# %%
soup.select('.item-multimedia-container')
# Out:
# [<article class="item item-multimedia-container" data-adid="92919993">
#  <picture class="item-multimedia">
#  <div class="item-multimedia-features">
#  <span class="icon-plans"></span>
#  </div>
#  <div class="item-multimedia-pictures">
#  <span class="icon-photos"></span> <span data-count=""></span><span data-total="">4</span>
#  </div>
#  <div class="item-ribbon-container">
#  </div>
#  <div class="item-gallery gallery-height-core-vitals neutral-orientation">
#  <picture class="gallery-fallback icon-no-pics">
#  <img alt="Primera foto del inmueble" class="" data-preloaded-img="true" height="225" src="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/aa/0d/ea/851102953.jpg" width="300"/>
#  </picture>
#  </div>
#  </picture>
#  <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/92919993/" role="heading" title="Piso en calle de Antonia Lancha, Opañel, Madrid">Piso en calle de Antonia Lancha, Opañel, Madrid</a>
# ...

# %%
items_id = soup.select('.item-multimedia-container')

# %%
items_id[0]
# Out:
# <article class="item item-multimedia-container" data-adid="92919993">
# <picture class="item-multimedia">
# <div class="item-multimedia-features">
# <span class="icon-plans"></span>
# </div>
# <div class="item-multimedia-pictures">
# <span class="icon-photos"></span> <span data-count=""></span><span data-total="">4</span>
# </div>
# <div class="item-ribbon-container">
# </div>
# <div class="item-gallery gallery-height-core-vitals neutral-orientation">
# <picture class="gallery-fallback icon-no-pics">
# <img alt="Primera foto del inmueble" class="" data-preloaded-img="true" height="225" src="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/aa/0d/ea/851102953.jpg" width="300"/>
# </picture>
# </div>
# </picture>
# <div class="item-info-container">
# <a aria-level="2" class="item-link" href="/inmueble/92919993/" role="heading" title="Piso en calle de Antonia Lancha, Opañel, Madrid">Piso en calle de Antonia Lancha, Opañel, Madrid</a>
# <div class="price-row">
# ...

# %%
len(soup.select('.item-multimedia-container'))
# Out:
# 30

# %%
items_id[0]['data-adid']
# Out:
# '92919993'

# %%
id = [i['data-adid'] for i in items_id]

# %%
id
# Out:
# ['92919993',
#  '92395730',
#  '92920006',
#  '92634466',
#  '92919935',
#  '92743312',
#  '27697681',
#  '92765069',
#  '35016637',
#  '92776930',
#  '92919878',
#  '34933484',
#  '26652365',
#  '92920003',
#  '92919980',
#  '90624154',
#  '92914674',
#  '92910154',
#  '33964497',
#  '86068229',
#  '92913710',
#  '91888915',
#  '92919938',
#  '92634152',
#  '27170476',
#  '92847800',
#  '92919926',
#  '92611902',
#  '92919875',
#  '92865504']

# %% [markdown]
# ### #Card: 2 - Get Title

# %%
soup.select('.item-link[title]')
# Out:
# [<a aria-level="2" class="item-link" href="/inmueble/92919993/" role="heading" title="Piso en calle de Antonia Lancha, Opañel, Madrid">Piso en calle de Antonia Lancha, Opañel, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92395730/" role="heading" title="Piso en calle de Espalter, Jerónimos, Madrid">Piso en calle de Espalter, Jerónimos, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92920006/" role="heading" title="Piso en avenida del Mediterráneo, Estrella, Madrid">Piso en avenida del Mediterráneo, Estrella, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92634466/" role="heading" title="Piso en calle de Pradillo, Ciudad Jardín, Madrid">Piso en calle de Pradillo, Ciudad Jardín, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92919935/" role="heading" title="Piso en Sanchinarro, Madrid">Piso en Sanchinarro, Madrid</a>,
# ...

# %%
len(soup.select('.item-link[title]'))
# Out:
# 30

# %%
items_ti = soup.select('.item-link[title]')

# %%
items_ti[0]['title']
# Out:
# 'Piso en calle de Antonia Lancha, Opañel, Madrid'

# %%
ti = [i['title'] for i in items_ti]

# %%
ti
# Out:
# ['Piso en calle de Antonia Lancha, Opañel, Madrid',
#  'Piso en calle de Espalter, Jerónimos, Madrid',
#  'Piso en avenida del Mediterráneo, Estrella, Madrid',
#  'Piso en calle de Pradillo, Ciudad Jardín, Madrid',
#  'Piso en Sanchinarro, Madrid',
#  'Piso en calle Sánchez Pacheco, 16, Ciudad Jardín, Madrid',
#  'Ático en calle Hachero, San Diego, Madrid',
#  'Piso en calle Alonso Castrillo, 24, Cuzco-Castillejos, Madrid',
#  'Estudio en Hachero, San Diego, Madrid',
#  'Piso en calle Castillo de Candanchú, Las Tablas, Madrid',
#  'Estudio en calle de San Marcos, Chueca-Justicia, Madrid',
#  'Piso en calle del Doce de Octubre, 16, Niño Jesús, Madrid',
#  'Piso en avenida General Ricardos, San Isidro, Madrid',
#  'Estudio en calle de Núñez de Balboa, 114, Castellana, Madrid',
#  'Piso en calle de Alicun, 7, Apóstol Santiago, Madrid',
#  'Piso en plaza de las Cortes, 3, Huertas-Cortes, Madrid',
#  'Ático en calle Mariano Vela, 23, Pradolongo, Madrid',
# ...

# %% [markdown]
# ### #Card: 3 - Number of Rooms

# %%
len(soup.select('.item-info-container>span:first-of-type'))
# Out:
# 30

# %%
items_ro= soup.select('.item-info-container>span:first-of-type')

# %%
items_ro[0].text.split(' ')[0]
# Out:
# '2'

# %%
ro = [i.text.split(' ')[0] for i in items_ro]

# %%
ro
# Out:
# ['2',
#  '3',
#  '3',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '33',
#  '3',
#  '44',
#  '2',
#  '1',
#  '40',
#  '3',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '4',
#  '3',
#  '40',
#  '2',
#  '3',
#  '2',
#  '1',
#  '1',
#  '35']

# %% [markdown]
# ### #Card: 4 - Type of dwelling

# %%
soup.select('.item-link[title]')
# Out:
# [<a aria-level="2" class="item-link" href="/inmueble/92919993/" role="heading" title="Piso en calle de Antonia Lancha, Opañel, Madrid">Piso en calle de Antonia Lancha, Opañel, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92395730/" role="heading" title="Piso en calle de Espalter, Jerónimos, Madrid">Piso en calle de Espalter, Jerónimos, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92920006/" role="heading" title="Piso en avenida del Mediterráneo, Estrella, Madrid">Piso en avenida del Mediterráneo, Estrella, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92634466/" role="heading" title="Piso en calle de Pradillo, Ciudad Jardín, Madrid">Piso en calle de Pradillo, Ciudad Jardín, Madrid</a>,
#  <a aria-level="2" class="item-link" href="/inmueble/92919935/" role="heading" title="Piso en Sanchinarro, Madrid">Piso en Sanchinarro, Madrid</a>,
# ...

# %%
items_ty = soup.select('.item-link[title]')

# %%
items_ty[0].text.split(' ')[0]
# Out:
# 'Piso'

# %%
ty = [i.text.split(' ')[0] for i in items_ty]

# %%
ty
# Out:
# ['Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Ático',
#  'Piso',
#  'Estudio',
#  'Piso',
#  'Estudio',
#  'Piso',
#  'Piso',
#  'Estudio',
#  'Piso',
#  'Piso',
#  'Ático',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Estudio',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Piso',
#  'Estudio']

# %% [markdown]
# .item-detail ~span

# %% [markdown]
# ### #Card: 5 - Squared Metters

# %%
soup.select('.item-detail~span')
# Out:
# [<span class="item-detail">75 <small>m²</small></span>,
#  <span class="item-detail">1ª planta <small>exterior con ascensor</small></span>,
#  <span class="item-detail"><small class="txt-highlight-red">2 minutos</small></span>,
#  <span class="item-detail">222 <small>m²</small></span>,
#  <span class="item-detail">4ª planta <small>exterior con ascensor</small></span>,
#  <span class="item-detail">132 <small>m²</small></span>,
#  <span class="item-detail">4ª planta <small>exterior con ascensor</small></span>,
#  <span class="item-detail"><small class="txt-highlight-red">6 minutos</small></span>,
#  <span class="item-detail">70 <small>m²</small></span>,
#  <span class="item-detail">2ª planta <small>exterior con ascensor</small></span>,
#  <span class="item-detail">70 <small>m²</small></span>,
#  <span class="item-detail">1ª planta <small>exterior con ascensor</small></span>,
#  <span class="item-detail"><small class="txt-highlight-red">10 minutos</small></span>,
# ...

# %%
items_sq = soup.select('.item-detail~span')

# %%
items_sq[0].text
# Out:
# '75 m²'

# %%
len([i.text for i in items_sq if 'm²' in i.text])
# Out:
# 25

# %%
sq = [i.text.strip('m²').strip(' ') for i in items_sq if 'm²' in i.text]

# %%
sq
# Out:
# ['75',
#  '222',
#  '132',
#  '70',
#  '70',
#  '60',
#  '45',
#  '95',
#  '110',
#  '70',
#  '37',
#  '90',
#  '68',
#  '70',
#  '101',
#  '35',
#  '57',
#  '45',
#  '90',
#  '160',
#  '78',
#  '115',
#  '52',
#  '52',
#  '45']

# %% [markdown]
# ### #Card: 6 - Price

# %%
soup.select('.item-price')
# Out:
# [<span class="item-price h2-simulated">1.150<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">4.300<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">1.350<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">1.200<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">975<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">900<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">500<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">1.400<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">450<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">1.300<span class="txt-big">€/mes</span></span>,
#  <span class="item-price h2-simulated">574<span class="txt-big">€/mes</span></span>,
# ...

# %%
len(soup.select('.item-price'))
# Out:
# 30

# %%
item_pr = soup.select('.item-price')

# %%
item_pr[0].text.strip('€/mes')
# Out:
# '1.150'

# %%
pr = [i.text.strip('€/mes') if '.' not in i.text else (i.text.strip('€/mes').replace('.', '')) for i in item_pr]

# %%
pr
# Out:
# ['1150',
#  '4300',
#  '1350',
#  '1200',
#  '975',
#  '900',
#  '500',
#  '1400',
#  '450',
#  '1300',
#  '574',
#  '1100',
#  '580',
#  '800',
#  '950',
#  '1300',
#  '550',
#  '1800',
#  '550',
#  '1000',
#  '600',
#  '1300',
#  '2500',
#  '600',
#  '1150',
#  '950',
#  '800',
#  '595',
#  '850',
#  '700']

# %% [markdown]
# ### #Card: 6 - Locations

# %% [markdown]
# * https://pypi.org/project/geopy/
# * https://geopy.readthedocs.io/en/latest/#specifying-parameters-once

# %%
#pip install geopy.geocoders

# %%
#from geopy.geocoders import Nominatim
#geolocator = Nominatim(user_agent="academic_app")

# %%
#help(geopy)

# %% [markdown]
# ```python
# from geopy.geocoders import Nominatim
# address = "Pasaje de Áncora Barrio Palos de Moguer Distrito Arganzuela Madrid"
# geolocator = Nominatim(user_agent="academic_app")
# location = geolocator.geocode("Pasaje de Áncora, Barrio Palos de Moguer, Distrito Arganzuela, Madrid")
# print(location.address)
#
# print((location.latitude, location.longitude))"""
# ```

# %% [markdown]
# To get the address we need to go inside of the every item and retrive the exact ubication

# %%
headers = """accept: text/plain, */*; q=0.01
accept-encoding: gzip, deflate, br
accept-language: es-ES,es;q=0.9,fr;q=0.8,en;q=0.7,pl;q=0.6
cache-control: no-cache
origin: https://www.idealista.com
pragma: no-cache
referer: https://www.idealista.com/
sec-ch-ua: "Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
url2 = 'https://www.idealista.com/inmueble/92919993/'

# %%
r.get(url2, headers=headers)
# Out:
# <Response [403]>

# %%
resp2 = r.get(url2, headers=headers)

# %%
soup2 = BeautifulSoup(resp2. content)

# %%
soup2
# Out:
# <html><head><title>idealista.com</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script>var dd={'cid':'AHrlqAAAAAMAEtJs3ijBkOkAXKljLA==','hsh':'AC81AADC3279CA4C7B968B717FBB30','t':'fe','s':17156,'host':'geo.captcha-delivery.com'}</script><script src="https://ct.captcha-delivery.com/c.js"></script></body></html>

# %%
for i in id:
    url2 = f'https://www.idealista.com/inmueble/{i}/'
    resp2=r.get(url2, headers=headers2)
    soup2 = BeautifulSoup(resp2. content)
    item_ad_st = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')
    str_street = item_ad_st[0].text.strip('\n')
    street = [] 
    street.append(str_street)
    item_ad_ng = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(2)')
    neighborhood = []
    str_neighborhood = "".join(item_ad_ng[0].text.strip('\n').split(' ')[1:])
    neighborhood.append(str_street)
    item_ad_dt = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(3)')
    district = []
    str_district = "".join(item_ad_dt[0].text.strip('\n').split(' ')[1:])
    neighborhood.append(str_street)
    city = []
    city.append('Madrid')
    time.sleep(2)
# Out:
# https://www.idealista.com/inmueble/92919993/
# <Response [200]>
# <!DOCTYPE html>
# <html data-userauth="false" env="es" lang="es" username="">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Alquiler de Piso en calle de Antonia Lancha, Opañel, Madrid — idealista</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="piso de 75 m², Alquiler de Piso en calle de Antonia Lancha, Opañel, Madrid, barrio Opañel" name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <script src="https://st1.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-consent-lang.js"></script>
# ...

# %%
soup2
# Out:
# <html><head><title>idealista.com</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script>var dd={'cid':'AHrlqAAAAAMAg-BEN4rm5P8AXKljLA==','hsh':'AC81AADC3279CA4C7B968B717FBB30','t':'fe','s':17156,'host':'geo.captcha-delivery.com'}</script><script src="https://ct.captcha-delivery.com/c.js"></script></body></html>

# %%
url2 = f'https://www.idealista.com/inmueble/92919993/'
resp2=r.get(url2, headers=headers)
soup2 = BeautifulSoup(resp2. content)
item_ad_st = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')
item_ad_st
# Out:
# []

# %%
print(soup2.history)
# Out:
# None

# %%
item_ad_st = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')
item_ad_st
# Out:
# []

# %%
url2 = 'https://www.idealista.com/inmueble/92919993/'
resp2=r.get(url2, headers=headers2)
soup2 = BeautifulSoup(resp2. content)
item_ad_st = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')
item_ad_st
# Out:
# []

# %%
street = (item_ad_st[0].text.strip('\n')).capitalize()
item_ad_ng = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(2)')
neighborhood = "".join(item_ad_ng[0].text.strip('\n').split(' ')[1:])
item_ad_dt = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(3)')
district = "".join(item_ad_dt[0].text.strip('\n').split(' ')[1:])
city = 'Madrid'

# %%
item_ad_st = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')
street = (item_ad_st[0].text.strip('\n')).capitalize()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-227-565d7c978c79> in <module>
#       1 item_ad_st = soup2.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')
# ----> 2 street = (item_ad_st[0].text.strip('\n')).capitalize()
#
# IndexError: list index out of range

# %%
soup2
# Out:
# <!DOCTYPE html>
# <html data-userauth="false" env="es" lang="es" username="">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Viviendas venta. Viviendas alquiler. Pisos. Chalets — idealista </title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="¿Buscas vivienda? Economiza tiempo y dinero con idealista, el portal inmobiliario donde puedes comprar, alquilar o vender tu casa, piso, chalet, finca u oficina de forma rápida y sencilla en España" name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# ...

# %%
city
# Out:
# 'Madrid'

# %%
[i.text for i in soup.select('div.clearfix:nth-child(1) ul:nth-child(2) > li:nth-child(1)')]

# %%
from requests.exceptions import SSLError, Timeout, TooManyRedirects, RequestException
from contextlib import closing
from IPython.display import Markdown, display
import warnings

warnings.filterwarnings('ignore')


timeout_glob=0.05
verify_glob=True
allow_glob=False

def printmd(string):
    display(Markdown('**'+string+'**'))
    
def is_good_response(x):
    """
    Returns True if the response seems to be an HTML, False otherwise
    x is response
    """
    
    content_type=x.headers['Content-Type'].lower()
    
    return ((x.status_code==200 and content_type is not None and content_type.find('html')>1), x.status_code)

def log_error(e):
    print(e)
    
    
def status_handler(status):
    if status<300:
        print('Alles gut!')
    elif status>=400 and status<500:
        print('request has failed due to you mistake bro. Check the link, headers, server and whether you have an access to this page.')
    else:
        print('Yoooo, I have no clue what has happened. But you are stuck, since you didnt receive any output from server')
    return None


def adaptive_scraping(url, timeout=timeout_glob, verify=verify_glob):
    global timeout_glob
    global verify_glob
    global allow_glob
    import requests as r
    
    try:
        with closing(r.get(url, stream=True, timeout=timeout_glob, verify=verify_glob, allow_redirects=allow_glob)) as resp:
            test1=is_good_response(resp)
            print(resp)
            if test1[0]:
                return resp.content
            else:
                return status_handler(test1[1])
    except Timeout as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('We can increase response waiting time. Do you want to continue?')
        ans=input('\n[Yes|No]\t')
        if ans.lower()=='yes':
            timeout_glob*=2
            return adaptive_scraping(url)
        else:
            return None
    except SSLError as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('We can skip verification test. Do you want to continue?')
        ans=input('\n[Yes|No]\t')
        if ans.lower()=='yes':
            verify_glob=False
            return adaptive_scraping(url)
        else:
            return None
    except TooManyRedirects as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('We can increase the number of allowed redirects. Do you want to continue?')
        ans=input('\n[Yes|No]\t')
        if ans.lower()=='yes':
            allow_glob=True
            return adaptive_scraping(url)
        else:
            return None
    except RequestException as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('Unfortunately, we have no clue what to do.  Please try again later. ')
        return None

# %%
adaptive_scraping(url2)
# Out:
# <Response [403]>
# request has failed due to you mistake bro. Check the link, headers, server and whether you have an access to this page.
