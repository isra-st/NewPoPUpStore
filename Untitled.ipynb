# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
from getpass import getpass
from sqlalchemy import inspect
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import requests as r
import re
import geopy

# %%
url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=3&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'

# %%
r.get(url)
# Out:
# <Response [200]>

# %%
headers = """accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: es-ES,es;q=0.9,fr;q=0.8,en;q=0.7,pl;q=0.6
cache-control: no-cache
origin: https://www.fotocasa.es
pragma: no-cache
referer: https://www.fotocasa.es/
sec-ch-ua: "Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
resp = r.get(url, headers=headers)

# %%
resp.json()
# Out:
# {'breadcrumb': {'countries': [],
#   'provinces': [],
#   'regions': [],
#   'municipalities': [{'literal': ' Madrid Capital',
#     'combinedLocation': '724,14,28,173,0,28079,0,0,0',
#     'counter': 2349,
#     'segments': 'madrid-capital/todas-las-zonas',
#     'selected': True,
#     'subLocations': None}],
#   'localities': [],
#   'districts': [{'literal': 'Arganzuela',
#     'combinedLocation': '724,14,28,173,0,28079,0,671,0',
#     'counter': 71,
#     'segments': 'madrid-capital/arganzuela',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Barajas',
#     'combinedLocation': '724,14,28,173,0,28079,0,668,0',
#     'counter': 47,
#     'segments': 'madrid-capital/barajas',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Carabanchel',
#     'combinedLocation': '724,14,28,173,0,28079,0,171,0',
#     'counter': 56,
#     'segments': 'madrid-capital/carabanchel',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Centro',
#     'combinedLocation': '724,14,28,173,0,28079,0,672,0',
#     'counter': 316,
#     'segments': 'madrid-capital/centro',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Chamartín',
#     'combinedLocation': '724,14,28,173,0,28079,0,176,0',
#     'counter': 221,
#     'segments': 'madrid-capital/chamartin',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Chamberí',
#     'combinedLocation': '724,14,28,173,0,28079,0,177,0',
#     'counter': 256,
#     'segments': 'madrid-capital/chamberi',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Ciudad Lineal',
#     'combinedLocation': '724,14,28,173,0,28079,0,685,0',
#     'counter': 113,
#     'segments': 'madrid-capital/ciudad-lineal',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Fuencarral',
#     'combinedLocation': '724,14,28,173,0,28079,0,187,0',
#     'counter': 97,
#     'segments': 'madrid-capital/fuencarral',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Hortaleza',
#     'combinedLocation': '724,14,28,173,0,28079,0,678,0',
#     'counter': 148,
#     'segments': 'madrid-capital/hortaleza',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Latina',
#     'combinedLocation': '724,14,28,173,0,28079,0,675,0',
#     'counter': 25,
#     'segments': 'madrid-capital/latina',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Moncloa',
#     'combinedLocation': '724,14,28,173,0,28079,0,669,0',
#     'counter': 112,
#     'segments': 'madrid-capital/moncloa',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Moratalaz',
#     'combinedLocation': '724,14,28,173,0,28079,0,191,0',
#     'counter': 11,
#     'segments': 'madrid-capital/moratalaz',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Puente de Vallecas',
#     'combinedLocation': '724,14,28,173,0,28079,0,677,0',
#     'counter': 21,
#     'segments': 'madrid-capital/puente-de-vallecas',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Retiro',
#     'combinedLocation': '724,14,28,173,0,28079,0,199,0',
#     'counter': 135,
#     'segments': 'madrid-capital/retiro',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Salamanca',
#     'combinedLocation': '724,14,28,173,0,28079,0,667,0',
#     'counter': 414,
#     'segments': 'madrid-capital/salamanca',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'San Blas',
#     'combinedLocation': '724,14,28,173,0,28079,0,676,0',
#     'counter': 65,
#     'segments': 'madrid-capital/san-blas',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Tetuán',
#     'combinedLocation': '724,14,28,173,0,28079,0,681,0',
#     'counter': 149,
#     'segments': 'madrid-capital/tetuan',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Usera',
#     'combinedLocation': '724,14,28,173,0,28079,0,205,0',
#     'counter': 15,
#     'segments': 'madrid-capital/usera',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Vicálvaro',
#     'combinedLocation': '724,14,28,173,0,28079,0,209,0',
#     'counter': 12,
#     'segments': 'madrid-capital/vicalvaro',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Villa de Vallecas',
#     'combinedLocation': '724,14,28,173,0,28079,0,680,0',
#     'counter': 22,
#     'segments': 'madrid-capital/villa-de-vallecas',
#     'selected': False,
#     'subLocations': None},
#    {'literal': 'Villaverde',
#     'combinedLocation': '724,14,28,173,0,28079,0,670,0',
#     'counter': 39,
#     'segments': 'madrid-capital/villaverde',
#     'selected': False,
#     'subLocations': None}],
#   'neighborhoods': [],
#   'edistricts': [{'literal': 'Arganzuela',
#     'combinedLocation': '724,14,28,173,0,28079,0,671,0',
#     'counter': 71,
#     'segments': 'madrid-capital/arganzuela',
#     'selected': False,
#     'subLocations': [{'literal': 'Acacias',
#       'combinedLocation': '724,14,28,173,0,28079,0,671,40',
#       'counter': 14,
#       'segments': 'madrid-capital/acacias',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Chopera',
#       'combinedLocation': '724,14,28,173,0,28079,0,671,41',
#       'counter': 10,
#       'segments': 'madrid-capital/chopera',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Delicias',
#       'combinedLocation': '724,14,28,173,0,28079,0,671,44',
#       'counter': 19,
#       'segments': 'madrid-capital/delicias',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Imperial',
#       'combinedLocation': '724,14,28,173,0,28079,0,671,42',
#       'counter': 13,
#       'segments': 'madrid-capital/imperial',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Legazpi de Madrid',
#       'combinedLocation': '724,14,28,173,0,28079,0,671,43',
#       'counter': 4,
#       'segments': 'madrid-capital/legazpi-de-madrid',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Palos de Moguer',
#       'combinedLocation': '724,14,28,173,0,28079,0,671,45',
#       'counter': 11,
#       'segments': 'madrid-capital/palos-de-moguer',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Barajas',
#     'combinedLocation': '724,14,28,173,0,28079,0,668,0',
#     'counter': 47,
#     'segments': 'madrid-capital/barajas',
#     'selected': False,
#     'subLocations': [{'literal': 'Alameda de Osuna',
#       'combinedLocation': '724,14,28,173,0,28079,0,668,26',
#       'counter': 18,
#       'segments': 'madrid-capital/alameda-de-osuna',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Casco Histórico de Barajas',
#       'combinedLocation': '724,14,28,173,0,28079,0,668,24',
#       'counter': 8,
#       'segments': 'madrid-capital/casco-historico-de-barajas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Corralejos - Campo de las Naciones',
#       'combinedLocation': '724,14,28,173,0,28079,0,668,23',
#       'counter': 11,
#       'segments': 'madrid-capital/corralejos-campo-de-las-naciones',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Timón',
#       'combinedLocation': '724,14,28,173,0,28079,0,668,25',
#       'counter': 10,
#       'segments': 'madrid-capital/timon',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Carabanchel',
#     'combinedLocation': '724,14,28,173,0,28079,0,171,0',
#     'counter': 56,
#     'segments': 'madrid-capital/carabanchel',
#     'selected': False,
#     'subLocations': [{'literal': 'Abrantes',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,95',
#       'counter': 3,
#       'segments': 'madrid-capital/abrantes',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Buenavista',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,96',
#       'counter': 9,
#       'segments': 'madrid-capital/buenavista',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Comillas',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,97',
#       'counter': 3,
#       'segments': 'madrid-capital/comillas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Opañel',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,98',
#       'counter': 10,
#       'segments': 'madrid-capital/opanel',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'PAU de Carabanchel',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,99',
#       'counter': 8,
#       'segments': 'madrid-capital/pau-de-carabanchel',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Puerta bonita',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,100',
#       'counter': 8,
#       'segments': 'madrid-capital/puerta-bonita',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Isidro',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,101',
#       'counter': 13,
#       'segments': 'madrid-capital/san-isidro',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Vista Alegre',
#       'combinedLocation': '724,14,28,173,0,28079,0,171,102',
#       'counter': 2,
#       'segments': 'madrid-capital/vista-alegre',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Centro',
#     'combinedLocation': '724,14,28,173,0,28079,0,672,0',
#     'counter': 316,
#     'segments': 'madrid-capital/centro',
#     'selected': False,
#     'subLocations': [{'literal': 'Cortes - Huertas',
#       'combinedLocation': '724,14,28,173,0,28079,0,672,47',
#       'counter': 35,
#       'segments': 'madrid-capital/cortes-huertas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Embajadores - Lavapiés',
#       'combinedLocation': '724,14,28,173,0,28079,0,672,48',
#       'counter': 42,
#       'segments': 'madrid-capital/embajadores-lavapies',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Justicia - Chueca',
#       'combinedLocation': '724,14,28,173,0,28079,0,672,46',
#       'counter': 99,
#       'segments': 'madrid-capital/justicia-chueca',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Palacio',
#       'combinedLocation': '724,14,28,173,0,28079,0,672,49',
#       'counter': 50,
#       'segments': 'madrid-capital/palacio',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Sol',
#       'combinedLocation': '724,14,28,173,0,28079,0,672,51',
#       'counter': 18,
#       'segments': 'madrid-capital/sol',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Universidad - Malasaña',
#       'combinedLocation': '724,14,28,173,0,28079,0,672,50',
#       'counter': 72,
#       'segments': 'madrid-capital/universidad-malasana',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Chamartín',
#     'combinedLocation': '724,14,28,173,0,28079,0,176,0',
#     'counter': 221,
#     'segments': 'madrid-capital/chamartin',
#     'selected': False,
#     'subLocations': [{'literal': 'Castilla',
#       'combinedLocation': '724,14,28,173,0,28079,0,176,112',
#       'counter': 34,
#       'segments': 'madrid-capital/castilla',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Ciudad Jardín',
#       'combinedLocation': '724,14,28,173,0,28079,0,176,113',
#       'counter': 22,
#       'segments': 'madrid-capital/ciudad-jardin',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'El Viso',
#       'combinedLocation': '724,14,28,173,0,28079,0,176,117',
#       'counter': 45,
#       'segments': 'madrid-capital/el-viso',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Hispanoamérica - Bernabéu',
#       'combinedLocation': '724,14,28,173,0,28079,0,176,115',
#       'counter': 47,
#       'segments': 'madrid-capital/hispanoamerica-bernabeu',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Nueva España',
#       'combinedLocation': '724,14,28,173,0,28079,0,176,114',
#       'counter': 38,
#       'segments': 'madrid-capital/nueva-espana',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Prosperidad',
#       'combinedLocation': '724,14,28,173,0,28079,0,176,116',
#       'counter': 35,
#       'segments': 'madrid-capital/prosperidad',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Chamberí',
#     'combinedLocation': '724,14,28,173,0,28079,0,177,0',
#     'counter': 256,
#     'segments': 'madrid-capital/chamberi',
#     'selected': False,
#     'subLocations': [{'literal': 'Almagro',
#       'combinedLocation': '724,14,28,173,0,28079,0,177,139',
#       'counter': 76,
#       'segments': 'madrid-capital/almagro',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Arapiles',
#       'combinedLocation': '724,14,28,173,0,28079,0,177,138',
#       'counter': 28,
#       'segments': 'madrid-capital/arapiles',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Gaztambide',
#       'combinedLocation': '724,14,28,173,0,28079,0,177,140',
#       'counter': 25,
#       'segments': 'madrid-capital/gaztambide',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Ríos Rosas - Nuevos Ministerios',
#       'combinedLocation': '724,14,28,173,0,28079,0,177,142',
#       'counter': 49,
#       'segments': 'madrid-capital/rios-rosas-nuevos-ministerios',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Trafalgar',
#       'combinedLocation': '724,14,28,173,0,28079,0,177,141',
#       'counter': 46,
#       'segments': 'madrid-capital/trafalgar',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Vallehermoso',
#       'combinedLocation': '724,14,28,173,0,28079,0,177,137',
#       'counter': 32,
#       'segments': 'madrid-capital/vallehermoso',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Ciudad Lineal',
#     'combinedLocation': '724,14,28,173,0,28079,0,685,0',
#     'counter': 113,
#     'segments': 'madrid-capital/ciudad-lineal',
#     'selected': False,
#     'subLocations': [{'literal': 'Atalaya',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,135',
#       'counter': 6,
#       'segments': 'madrid-capital/atalaya',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Colina',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,136',
#       'counter': 8,
#       'segments': 'madrid-capital/colina',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Concepción',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,134',
#       'counter': 22,
#       'segments': 'madrid-capital/concepcion',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Costillares',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,131',
#       'counter': 17,
#       'segments': 'madrid-capital/costillares',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Pueblo Nuevo',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,132',
#       'counter': 11,
#       'segments': 'madrid-capital/pueblo-nuevo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Quintana',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,128',
#       'counter': 12,
#       'segments': 'madrid-capital/quintana',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Juan Bautista',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,129',
#       'counter': 11,
#       'segments': 'madrid-capital/san-juan-bautista',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Pascual de Madrid',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,130',
#       'counter': 13,
#       'segments': 'madrid-capital/san-pascual-de-madrid',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Ventas',
#       'combinedLocation': '724,14,28,173,0,28079,0,685,133',
#       'counter': 13,
#       'segments': 'madrid-capital/ventas',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Fuencarral',
#     'combinedLocation': '724,14,28,173,0,28079,0,187,0',
#     'counter': 97,
#     'segments': 'madrid-capital/fuencarral',
#     'selected': False,
#     'subLocations': [{'literal': 'Arroyo del Fresno',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,817',
#       'counter': 7,
#       'segments': 'madrid-capital/arroyo-del-fresno',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'El Pardo',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,9',
#       'counter': 1,
#       'segments': 'madrid-capital/el-pardo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Fuentelarreina',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,8',
#       'counter': 1,
#       'segments': 'madrid-capital/fuentelarreina',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'La Paz',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,10',
#       'counter': 12,
#       'segments': 'madrid-capital/la-paz',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Las Tablas',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,11',
#       'counter': 19,
#       'segments': 'madrid-capital/las-tablas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Mirasierra',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,12',
#       'counter': 5,
#       'segments': 'madrid-capital/mirasierra',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Montecarmelo',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,13',
#       'counter': 15,
#       'segments': 'madrid-capital/montecarmelo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Peñagrande',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,14',
#       'counter': 16,
#       'segments': 'madrid-capital/penagrande',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Pilar',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,15',
#       'counter': 10,
#       'segments': 'madrid-capital/pilar',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Tres Olivos - Valverde',
#       'combinedLocation': '724,14,28,173,0,28079,0,187,16',
#       'counter': 11,
#       'segments': 'madrid-capital/tres-olivos-valverde',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Hortaleza',
#     'combinedLocation': '724,14,28,173,0,28079,0,678,0',
#     'counter': 148,
#     'segments': 'madrid-capital/hortaleza',
#     'selected': False,
#     'subLocations': [{'literal': 'Apóstol Santiago',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,86',
#       'counter': 2,
#       'segments': 'madrid-capital/apostol-santiago',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Canillas',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,87',
#       'counter': 28,
#       'segments': 'madrid-capital/canillas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Conde Orgaz - Piovera',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,90',
#       'counter': 31,
#       'segments': 'madrid-capital/conde-orgaz-piovera',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Palomas',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,88',
#       'counter': 12,
#       'segments': 'madrid-capital/palomas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Pinar del Rey',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,89',
#       'counter': 18,
#       'segments': 'madrid-capital/pinar-del-rey',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Sanchinarro',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,91',
#       'counter': 38,
#       'segments': 'madrid-capital/sanchinarro',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Valdebebas - Valdefuentes',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,92',
#       'counter': 6,
#       'segments': 'madrid-capital/valdebebas-valdefuentes',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Virgen del Cortijo - Manoteras',
#       'combinedLocation': '724,14,28,173,0,28079,0,678,93',
#       'counter': 13,
#       'segments': 'madrid-capital/virgen-del-cortijo-manoteras',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Latina',
#     'combinedLocation': '724,14,28,173,0,28079,0,675,0',
#     'counter': 25,
#     'segments': 'madrid-capital/latina',
#     'selected': False,
#     'subLocations': [{'literal': 'Águilas',
#       'combinedLocation': '724,14,28,173,0,28079,0,675,68',
#       'counter': 3,
#       'segments': 'madrid-capital/aguilas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Aluche',
#       'combinedLocation': '724,14,28,173,0,28079,0,675,65',
#       'counter': 2,
#       'segments': 'madrid-capital/aluche',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Campamento',
#       'combinedLocation': '724,14,28,173,0,28079,0,675,67',
#       'counter': 2,
#       'segments': 'madrid-capital/campamento',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Lucero',
#       'combinedLocation': '724,14,28,173,0,28079,0,675,69',
#       'counter': 5,
#       'segments': 'madrid-capital/lucero',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Puerta del Ángel',
#       'combinedLocation': '724,14,28,173,0,28079,0,675,66',
#       'counter': 13,
#       'segments': 'madrid-capital/puerta-del-angel',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Moncloa',
#     'combinedLocation': '724,14,28,173,0,28079,0,669,0',
#     'counter': 112,
#     'segments': 'madrid-capital/moncloa',
#     'selected': False,
#     'subLocations': [{'literal': 'Aravaca',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,29',
#       'counter': 20,
#       'segments': 'madrid-capital/aravaca',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Argüelles',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,33',
#       'counter': 43,
#       'segments': 'madrid-capital/arguelles',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Casa de Campo',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,31',
#       'counter': 3,
#       'segments': 'madrid-capital/casa-de-campo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Ciudad Universitaria',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,34',
#       'counter': 12,
#       'segments': 'madrid-capital/ciudad-universitaria',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'La Florida -  El  Plantío',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,32',
#       'counter': 5,
#       'segments': 'madrid-capital/la-florida-el-plantio',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Valdemarín',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,28',
#       'counter': 18,
#       'segments': 'madrid-capital/valdemarin',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Valdezarza',
#       'combinedLocation': '724,14,28,173,0,28079,0,669,30',
#       'counter': 11,
#       'segments': 'madrid-capital/valdezarza',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Moratalaz',
#     'combinedLocation': '724,14,28,173,0,28079,0,191,0',
#     'counter': 11,
#     'segments': 'madrid-capital/moratalaz',
#     'selected': False,
#     'subLocations': [{'literal': 'Fontarrón',
#       'combinedLocation': '724,14,28,173,0,28079,0,191,54',
#       'counter': 1,
#       'segments': 'madrid-capital/fontarron',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Horcajo',
#       'combinedLocation': '724,14,28,173,0,28079,0,191,52',
#       'counter': 2,
#       'segments': 'madrid-capital/horcajo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Marroquina',
#       'combinedLocation': '724,14,28,173,0,28079,0,191,56',
#       'counter': 3,
#       'segments': 'madrid-capital/marroquina',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Media Legua',
#       'combinedLocation': '724,14,28,173,0,28079,0,191,55',
#       'counter': 1,
#       'segments': 'madrid-capital/media-legua',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Vinateros',
#       'combinedLocation': '724,14,28,173,0,28079,0,191,57',
#       'counter': 3,
#       'segments': 'madrid-capital/vinateros',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Puente de Vallecas',
#     'combinedLocation': '724,14,28,173,0,28079,0,677,0',
#     'counter': 21,
#     'segments': 'madrid-capital/puente-de-vallecas',
#     'selected': False,
#     'subLocations': [{'literal': 'Numancia',
#       'combinedLocation': '724,14,28,173,0,28079,0,677,82',
#       'counter': 5,
#       'segments': 'madrid-capital/numancia',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Palomeras Bajas',
#       'combinedLocation': '724,14,28,173,0,28079,0,677,80',
#       'counter': 2,
#       'segments': 'madrid-capital/palomeras-bajas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Palomeras Sureste',
#       'combinedLocation': '724,14,28,173,0,28079,0,677,85',
#       'counter': 4,
#       'segments': 'madrid-capital/palomeras-sureste',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Portazgo',
#       'combinedLocation': '724,14,28,173,0,28079,0,677,84',
#       'counter': 2,
#       'segments': 'madrid-capital/portazgo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Diego',
#       'combinedLocation': '724,14,28,173,0,28079,0,677,83',
#       'counter': 8,
#       'segments': 'madrid-capital/san-diego',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Retiro',
#     'combinedLocation': '724,14,28,173,0,28079,0,199,0',
#     'counter': 135,
#     'segments': 'madrid-capital/retiro',
#     'selected': False,
#     'subLocations': [{'literal': 'Adelfas',
#       'combinedLocation': '724,14,28,173,0,28079,0,199,118',
#       'counter': 16,
#       'segments': 'madrid-capital/adelfas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Estrella',
#       'combinedLocation': '724,14,28,173,0,28079,0,199,123',
#       'counter': 12,
#       'segments': 'madrid-capital/estrella',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Ibiza de Madrid',
#       'combinedLocation': '724,14,28,173,0,28079,0,199,122',
#       'counter': 51,
#       'segments': 'madrid-capital/ibiza-de-madrid',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Jerónimos',
#       'combinedLocation': '724,14,28,173,0,28079,0,199,121',
#       'counter': 20,
#       'segments': 'madrid-capital/jeronimos',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Niño Jesús',
#       'combinedLocation': '724,14,28,173,0,28079,0,199,120',
#       'counter': 17,
#       'segments': 'madrid-capital/nino-jesus',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Pacífico',
#       'combinedLocation': '724,14,28,173,0,28079,0,199,119',
#       'counter': 19,
#       'segments': 'madrid-capital/pacifico',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Salamanca',
#     'combinedLocation': '724,14,28,173,0,28079,0,667,0',
#     'counter': 414,
#     'segments': 'madrid-capital/salamanca',
#     'selected': False,
#     'subLocations': [{'literal': 'Castellana',
#       'combinedLocation': '724,14,28,173,0,28079,0,667,19',
#       'counter': 64,
#       'segments': 'madrid-capital/castellana',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Fuente del Berro',
#       'combinedLocation': '724,14,28,173,0,28079,0,667,21',
#       'counter': 27,
#       'segments': 'madrid-capital/fuente-del-berro',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Goya',
#       'combinedLocation': '724,14,28,173,0,28079,0,667,18',
#       'counter': 89,
#       'segments': 'madrid-capital/goya',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Guindalera',
#       'combinedLocation': '724,14,28,173,0,28079,0,667,20',
#       'counter': 47,
#       'segments': 'madrid-capital/guindalera',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Lista',
#       'combinedLocation': '724,14,28,173,0,28079,0,667,22',
#       'counter': 77,
#       'segments': 'madrid-capital/lista',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Recoletos',
#       'combinedLocation': '724,14,28,173,0,28079,0,667,17',
#       'counter': 110,
#       'segments': 'madrid-capital/recoletos',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'San Blas',
#     'combinedLocation': '724,14,28,173,0,28079,0,676,0',
#     'counter': 65,
#     'segments': 'madrid-capital/san-blas',
#     'selected': False,
#     'subLocations': [{'literal': 'Amposta',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,75',
#       'counter': 2,
#       'segments': 'madrid-capital/amposta',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Arcos de Jalón',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,74',
#       'counter': 3,
#       'segments': 'madrid-capital/arcos-de-jalon',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Canillejas',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,77',
#       'counter': 1,
#       'segments': 'madrid-capital/canillejas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Hellín',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,79',
#       'counter': 2,
#       'segments': 'madrid-capital/hellin',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Rejas',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,73',
#       'counter': 14,
#       'segments': 'madrid-capital/rejas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Rosas - Musas',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,72',
#       'counter': 13,
#       'segments': 'madrid-capital/rosas-musas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Salvador',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,78',
#       'counter': 8,
#       'segments': 'madrid-capital/salvador',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Simancas',
#       'combinedLocation': '724,14,28,173,0,28079,0,676,76',
#       'counter': 22,
#       'segments': 'madrid-capital/simancas',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Tetuán',
#     'combinedLocation': '724,14,28,173,0,28079,0,681,0',
#     'counter': 149,
#     'segments': 'madrid-capital/tetuan',
#     'selected': False,
#     'subLocations': [{'literal': 'Almenara -Ventilla',
#       'combinedLocation': '724,14,28,173,0,28079,0,681,111',
#       'counter': 12,
#       'segments': 'madrid-capital/almenara-ventilla',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Bellas Vistas',
#       'combinedLocation': '724,14,28,173,0,28079,0,681,108',
#       'counter': 21,
#       'segments': 'madrid-capital/bellas-vistas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Berruguete',
#       'combinedLocation': '724,14,28,173,0,28079,0,681,109',
#       'counter': 11,
#       'segments': 'madrid-capital/berruguete',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Castillejos - Cuzco',
#       'combinedLocation': '724,14,28,173,0,28079,0,681,110',
#       'counter': 49,
#       'segments': 'madrid-capital/castillejos-cuzco',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Cuatro Caminos - Azca',
#       'combinedLocation': '724,14,28,173,0,28079,0,681,107',
#       'counter': 47,
#       'segments': 'madrid-capital/cuatro-caminos-azca',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Valdeacederas',
#       'combinedLocation': '724,14,28,173,0,28079,0,681,106',
#       'counter': 9,
#       'segments': 'madrid-capital/valdeacederas',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Usera',
#     'combinedLocation': '724,14,28,173,0,28079,0,205,0',
#     'counter': 15,
#     'segments': 'madrid-capital/usera',
#     'selected': False,
#     'subLocations': [{'literal': 'Almendrales',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,60',
#       'counter': 2,
#       'segments': 'madrid-capital/almendrales',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Moscardó',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,58',
#       'counter': 4,
#       'segments': 'madrid-capital/moscardo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Orcasitas',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,59',
#       'counter': 2,
#       'segments': 'madrid-capital/orcasitas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Orcasur - 12 de Octubre',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,61',
#       'counter': 1,
#       'segments': 'madrid-capital/orcasur-12-de-octubre',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Pradolongo',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,62',
#       'counter': 4,
#       'segments': 'madrid-capital/pradolongo',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Fermín',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,64',
#       'counter': 1,
#       'segments': 'madrid-capital/san-fermin',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Zofio',
#       'combinedLocation': '724,14,28,173,0,28079,0,205,63',
#       'counter': 1,
#       'segments': 'madrid-capital/zofio',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Vicálvaro',
#     'combinedLocation': '724,14,28,173,0,28079,0,209,0',
#     'counter': 12,
#     'segments': 'madrid-capital/vicalvaro',
#     'selected': False,
#     'subLocations': [{'literal': 'Ambroz',
#       'combinedLocation': '724,14,28,173,0,28079,0,209,124',
#       'counter': 2,
#       'segments': 'madrid-capital/ambroz',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'El Cañaveral - Los Berrocales',
#       'combinedLocation': '724,14,28,173,0,28079,0,209,126',
#       'counter': 5,
#       'segments': 'madrid-capital/el-canaveral-los-berrocales',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Valdebernardo - Valderribas',
#       'combinedLocation': '724,14,28,173,0,28079,0,209,127',
#       'counter': 5,
#       'segments': 'madrid-capital/valdebernardo-valderribas',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Villa de Vallecas',
#     'combinedLocation': '724,14,28,173,0,28079,0,680,0',
#     'counter': 22,
#     'segments': 'madrid-capital/villa-de-vallecas',
#     'selected': False,
#     'subLocations': [{'literal': 'Casco Histórico de Vallecas',
#       'combinedLocation': '724,14,28,173,0,28079,0,680,103',
#       'counter': 2,
#       'segments': 'madrid-capital/casco-historico-de-vallecas',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Ensanche de Vallecas - La Gavia',
#       'combinedLocation': '724,14,28,173,0,28079,0,680,104',
#       'counter': 19,
#       'segments': 'madrid-capital/ensanche-de-vallecas-la-gavia',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Santa Eugenia',
#       'combinedLocation': '724,14,28,173,0,28079,0,680,105',
#       'counter': 1,
#       'segments': 'madrid-capital/santa-eugenia',
#       'selected': False,
#       'subLocations': None}]},
#    {'literal': 'Villaverde',
#     'combinedLocation': '724,14,28,173,0,28079,0,670,0',
#     'counter': 39,
#     'segments': 'madrid-capital/villaverde',
#     'selected': False,
#     'subLocations': [{'literal': 'Butarque',
#       'combinedLocation': '724,14,28,173,0,28079,0,670,37',
#       'counter': 12,
#       'segments': 'madrid-capital/butarque',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Los Ángeles',
#       'combinedLocation': '724,14,28,173,0,28079,0,670,38',
#       'counter': 2,
#       'segments': 'madrid-capital/los-angeles',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'Los Rosales',
#       'combinedLocation': '724,14,28,173,0,28079,0,670,39',
#       'counter': 8,
#       'segments': 'madrid-capital/los-rosales',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Andrés de Villaverde',
#       'combinedLocation': '724,14,28,173,0,28079,0,670,36',
#       'counter': 15,
#       'segments': 'madrid-capital/san-andres-de-villaverde',
#       'selected': False,
#       'subLocations': None},
#      {'literal': 'San Cristóbal de Villaverde',
#       'combinedLocation': '724,14,28,173,0,28079,0,670,35',
#       'counter': 2,
#       'segments': 'madrid-capital/san-cristobal-de-villaverde',
#       'selected': False,
#       'subLocations': None}]}]},
#  'count': 2349,
#  'hrefLang': {'ca': {'location': 'madrid-capital',
#    'zone': 'totes-les-zones',
#    'text': ''},
#   'es': {'location': 'madrid-capital', 'zone': 'todas-las-zonas', 'text': ''},
#   'en': {'location': 'madrid-capital', 'zone': 'all-zones', 'text': ''},
#   'de': {'location': 'madrid-capital', 'zone': 'alle-zonen', 'text': ''}},
#  'client': None,
#  'realEstates': [{'id': 158979649,
#    'promotionId': 0,
#    'typeId': 2,
#    'subtypeId': 1,
#    'isNew': True,
#    'isPremium': False,
#    'advertiser': {'logo': {'multimedia': {'url': 'https://d.fotocasa.es/client/9202760384932/477593.jpg/100x52/',
#       'typeId': 8},
#      'url': {'es': '/inmobiliarias/verdanyo-inmobiliaria-sl-9202760384932'}},
#     'phone': '916350865',
#     'typeId': 3,
#     'clientId': 9202760384932,
#     'urlAlias': 'verdanyo-inmobiliaria-sl',
#     'clientAlias': 'VERDANYO INMOBILIARIA SL.'},
#    'detail': {'es': '/es/alquiler/vivienda/madrid-capital/aire-acondicionado-calefaccion-no-amueblado/158979649/d'},
#    'multimedias': [{'url': 'https://d.inmofactory.com/1/111635/27171697/371316769.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316823.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316819.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316767.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316772.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316794.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316836.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316796.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316797.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316798.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316801.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316803.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316804.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316807.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316810.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316813.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316816.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316821.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316881.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316886.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316892.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316875.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316827.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316761.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316904.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316931.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316762.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316766.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316753.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316757.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316760.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316940.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316943.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316947.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316830.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316832.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316953.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316954.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316959.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316839.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316842.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316845.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316969.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316975.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316847.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316851.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316855.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316859.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316865.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316871.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316899.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316910.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316913.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316917.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316923.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316929.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316933.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316938.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316944.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316949.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316951.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/111635/27171697/371316964.jpg',
#      'typeId': 2}],
#    'features': [{'key': 'bathrooms',
#      'value': [1],
#      'minValue': 0,
#      'maxValue': 0},
#     {'key': 'conservationState', 'value': [2], 'minValue': 0, 'maxValue': 0},
#     {'key': 'floor', 'value': [9], 'minValue': 0, 'maxValue': 0},
#     {'key': 'rooms', 'value': [2], 'minValue': 0, 'maxValue': 0},
#     {'key': 'surface', 'value': [80], 'minValue': 0, 'maxValue': 0}],
#    'otherFeatures': None,
#    'transactions': [{'transactionTypeId': 3,
#      'value': [1100],
#      'reduced': 0,
#      'periodicityId': 3,
#      'maxPrice': 0,
#      'minPrice': 0}],
#    'products': [],
#    'address': {'ubication': 'Calle de San Vicente Ferrer, Centro',
#     'location': {'country': 'España',
#      'level1': 'Madrid',
#      'level2': 'Madrid',
#      'level3': 'Madrid, Zona de',
#      'level4': '',
#      'level5': ' Madrid Capital',
#      'level6': '',
#      'level7': 'Centro',
#      'level8': 'Universidad - Malasaña',
#      'upperLevel': 'Universidad - Malasaña',
#      'countryId': 724,
#      'level1Id': 14,
#      'level2Id': 28,
#      'level3Id': 173,
#      'level4Id': 0,
#      'level5Id': 28079,
#      'level6Id': 0,
#      'level7Id': 672,
#      'level8Id': 50},
#     'coordinates': {'accuracy': 0,
#      'latitude': 40.42612,
#      'longitude': -3.708903},
#     'zipCode': '28015',
#     'customZone': None},
#    'date': '2021-02-19T10:01:51.263Z',
#    'description': 'Aseguramos Tu Alquiler - Alquila piso en Noviciado - Universidad. Una vivienda muy especial en ubicación inmejorable cerca de metro Noviciado. Es todo exterior en 4ª y última planta sin ascensor. Mucha luz, buena ventilación y especialmente tranquila. La cocina está equipada y el resto de la casa sin amueblar, excepto una cama doble. Todas las estancias son muy amplias, dos habitaciones dobles, salón grande, cocina independiente cuadrada, baño exterior amplio y muy luminoso, recibidor y espacio para despensa, armarios empotrados. Recién pintada, suelos de tarima.',
#    'isTop': False,
#    'isPhotoReport': False,
#    'isMsAdvance': False,
#    'promotionTypeId': 0,
#    'promotionUrl': None,
#    'isExternalContact': False,
#    'isVirtualTour': False},
#   {'id': 157856441,
#    'promotionId': 0,
#    'typeId': 2,
#    'subtypeId': 1,
#    'isNew': False,
#    'isPremium': False,
#    'advertiser': {'logo': {'multimedia': {'url': 'https://d.fotocasa.es/client/9202761958388/633159.jpg/100x52/',
#       'typeId': 8},
#      'url': {'es': '/inmobiliarias/servicheck-vallecas-9202761958388'}},
#     'phone': '912669715',
#     'typeId': 3,
#     'clientId': 9202761958388,
#     'urlAlias': 'servicheck-vallecas',
#     'clientAlias': 'SERVICHECK (VALLECAS)'},
#    'detail': {'es': '/es/alquiler/vivienda/madrid-capital/aire-acondicionado-no-amueblado/157856441/d'},
#    'multimedias': [{'url': 'https://d.inmofactory.com/1/114585/26161203/351110775.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110729.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110734.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110730.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110752.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110679.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110696.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110698.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110702.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110720.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110732.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/114585/26161203/351110772.jpg',
#      'typeId': 2}],
#    'features': [{'key': 'bathrooms',
#      'value': [1],
#      'minValue': 0,
#      'maxValue': 0},
#     {'key': 'floor', 'value': [4], 'minValue': 0, 'maxValue': 0},
#     {'key': 'rooms', 'value': [1], 'minValue': 0, 'maxValue': 0},
#     {'key': 'surface', 'value': [30], 'minValue': 0, 'maxValue': 0}],
#    'otherFeatures': None,
#    'transactions': [{'transactionTypeId': 3,
#      'value': [700],
#      'reduced': 30,
#      'periodicityId': 3,
#      'maxPrice': 0,
#      'minPrice': 0}],
#    'products': [],
#    'address': {'ubication': 'Calle de San Vicente Ferrer, Centro',
#     'location': {'country': 'España',
#      'level1': 'Madrid',
#      'level2': 'Madrid',
#      'level3': 'Madrid, Zona de',
#      'level4': '',
#      'level5': ' Madrid Capital',
#      'level6': '',
#      'level7': 'Centro',
#      'level8': 'Universidad - Malasaña',
#      'upperLevel': 'Universidad - Malasaña',
# ...
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743791.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743792.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743793.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743794.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743795.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743796.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743797.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743798.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743799.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743800.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743801.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743802.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743803.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27145774/370743804.jpg',
#      'typeId': 2},
#     {'url': 'https://player.vimeo.com/video/511085077', 'typeId': 21},
#     {'url': 'https://youtu.be/LzokkQMAOus', 'typeId': 21}],
#    'features': [{'key': 'bathrooms',
#      'value': [2],
#      'minValue': 0,
#      'maxValue': 0},
#     {'key': 'conservationState', 'value': [3], 'minValue': 0, 'maxValue': 0},
#     {'key': 'floor', 'value': [3], 'minValue': 0, 'maxValue': 0},
#     {'key': 'rooms', 'value': [3], 'minValue': 0, 'maxValue': 0},
#     {'key': 'surface', 'value': [150], 'minValue': 0, 'maxValue': 0}],
#    'otherFeatures': None,
#    'transactions': [{'transactionTypeId': 3,
#      'value': [3800],
#      'reduced': 0,
#      'periodicityId': 3,
#      'maxPrice': 0,
#      'minPrice': 0}],
#    'products': [{'id': 56}],
#    'address': {'ubication': 'Calle San Gregorio, 19, Centro',
#     'location': {'country': 'España',
#      'level1': 'Madrid',
#      'level2': 'Madrid',
#      'level3': 'Madrid, Zona de',
#      'level4': '',
#      'level5': ' Madrid Capital',
#      'level6': '',
#      'level7': 'Centro',
#      'level8': 'Justicia - Chueca',
#      'upperLevel': 'Justicia - Chueca',
#      'countryId': 724,
#      'level1Id': 14,
#      'level2Id': 28,
#      'level3Id': 173,
#      'level4Id': 0,
#      'level5Id': 28079,
#      'level6Id': 0,
#      'level7Id': 672,
#      'level8Id': 46},
#     'coordinates': {'accuracy': 1, 'latitude': 40.4241, 'longitude': -3.69716},
#     'zipCode': '28004',
#     'customZone': None},
#    'date': '2021-02-19T08:47:41.967Z',
#    'description': 'Vivienda-oficina de 150m² en una de las calles más representativas del barrio de Chueca, cercana al Tribunal Supremo y la Audiencia Nacional. Esta distribuida en dos plantas, consta de 3 amplias estancias que pueden ser usados como dormitorios o despachos, 1 sala de trabajo, 2 baños y cocina con office.\xa0 Reformada hace menos de un año, con las más altas calidades en todas las estancias, dispone de uno de los mejores sistemas de audio y video del mercado en todas las estancias. La iluminación es regulable y sistema domótico en toda la oficina, con posibilidad de controlar la iluminación y climatización. La zona tiene muy buena comunicación tanto en transporte privado, como en transporte público, ya que se encuentra muy cerca de la Calle Alcalá y del Paseo de la Castellana. A 20 minutos del Aeropuerto y a 10 minutos de la estación de Atocha.\xa0\r\n',
#    'isTop': False,
#    'isPhotoReport': False,
#    'isMsAdvance': False,
#    'promotionTypeId': 0,
#    'promotionUrl': None,
#    'isExternalContact': False,
#    'isVirtualTour': False},
#   {'id': 158936541,
#    'promotionId': 0,
#    'typeId': 2,
#    'subtypeId': 1,
#    'isNew': False,
#    'isPremium': False,
#    'advertiser': {'logo': {'multimedia': {'url': 'https://d.fotocasa.es/client/9202756368671/522261.jpg/100x52/',
#       'typeId': 8},
#      'url': {'es': '/inmobiliarias/aproperties-9202756368671'}},
#     'phone': '914890879',
#     'typeId': 3,
#     'clientId': 9202756368671,
#     'urlAlias': 'aproperties',
#     'clientAlias': 'APROPERTIES'},
#    'detail': {'es': '/es/alquiler/vivienda/madrid-capital/calefaccion-ascensor-se-aceptan-mascotas-no-amueblado/158936541/d'},
#    'multimedias': [{'url': 'https://d.inmofactory.com/1/103494/27125572/370371516.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371517.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371518.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371519.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371520.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371521.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371522.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371523.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371524.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371525.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371526.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371527.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371528.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371529.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371530.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371531.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371532.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371533.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371534.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371535.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371536.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371537.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371538.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371539.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371540.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371541.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27125572/370371542.jpg',
#      'typeId': 2},
#     {'url': 'https://player.vimeo.com/video/512879610', 'typeId': 21},
#     {'url': 'https://youtu.be/LzokkQMAOus', 'typeId': 21}],
#    'features': [{'key': 'bathrooms',
#      'value': [2],
#      'minValue': 0,
#      'maxValue': 0},
#     {'key': 'conservationState', 'value': [3], 'minValue': 0, 'maxValue': 0},
#     {'key': 'floor', 'value': [7], 'minValue': 0, 'maxValue': 0},
#     {'key': 'elevator', 'value': [1], 'minValue': 0, 'maxValue': 0},
#     {'key': 'rooms', 'value': [4], 'minValue': 0, 'maxValue': 0},
#     {'key': 'surface', 'value': [100], 'minValue': 0, 'maxValue': 0}],
#    'otherFeatures': None,
#    'transactions': [{'transactionTypeId': 3,
#      'value': [1550],
#      'reduced': 0,
#      'periodicityId': 3,
#      'maxPrice': 0,
#      'minPrice': 0}],
#    'products': [],
#    'address': {'ubication': 'Calle de Galileo, Chamberí',
#     'location': {'country': 'España',
#      'level1': 'Madrid',
#      'level2': 'Madrid',
#      'level3': 'Madrid, Zona de',
#      'level4': '',
#      'level5': ' Madrid Capital',
#      'level6': '',
#      'level7': 'Chamberí',
#      'level8': 'Arapiles',
#      'upperLevel': 'Arapiles',
#      'countryId': 724,
#      'level1Id': 14,
#      'level2Id': 28,
#      'level3Id': 173,
#      'level4Id': 0,
#      'level5Id': 28079,
#      'level6Id': 0,
#      'level7Id': 177,
#      'level8Id': 138},
#     'coordinates': {'accuracy': 0,
#      'latitude': 40.43696,
#      'longitude': -3.710246},
#     'zipCode': '28015',
#     'customZone': None},
#    'date': '2021-02-19T08:47:41.883Z',
#    'description': 'Situado en el prestigioso barrio de Chamberí, en la zona de Arapiles y muy bien comunicada se encuentra esta preciosa vivienda de 100m²\xa0de 4 dormitorios\xa0completamente reformada y a estrenar, muy luminosa y silenciosa. El piso cuenta con un salón amplio\xa0que da a un patio de manzana muy luminoso\xa0y la cocina se encuentra equipada con todos los electrodomésticos necesarios.\xa0Los cuatro dormitorios muy similares en tamaño tienen dos orientaciones distintas 2 hacia el mismo patio de manzana que da el salón y los otros dos a un patio un poco\xa0más\xa0pequeño pero muy luminoso. El piso cuenta con dos\xa0cuartos de baño\xa0completos ambos con ducha. La vivienda tiene los mejores acabados y calidades, suelos de tarima y calefacción central individualizada. Comunidad,\xa0ibi\xa0y agua incluida en el precio. La finca tiene ascensor y conserje.\xa0El precio es anunciado es durante los 2 primeros años a partir del tercer año el precio sería de 1.950€\xa0\r\n',
#    'isTop': False,
#    'isPhotoReport': False,
#    'isMsAdvance': False,
#    'promotionTypeId': 0,
#    'promotionUrl': None,
#    'isExternalContact': False,
#    'isVirtualTour': False},
#   {'id': 158935954,
#    'promotionId': 0,
#    'typeId': 2,
#    'subtypeId': 1,
#    'isNew': False,
#    'isPremium': False,
#    'advertiser': {'logo': {'multimedia': {'url': 'https://d.fotocasa.es/client/9202756368671/522261.jpg/100x52/',
#       'typeId': 8},
#      'url': {'es': '/inmobiliarias/aproperties-9202756368671'}},
#     'phone': '914890879',
#     'typeId': 3,
#     'clientId': 9202756368671,
#     'urlAlias': 'aproperties',
#     'clientAlias': 'APROPERTIES'},
#    'detail': {'es': '/es/alquiler/vivienda/madrid-capital/aire-acondicionado-calefaccion-ascensor-no-amueblado/158935954/d'},
#    'multimedias': [{'url': 'https://d.inmofactory.com/1/103494/27124517/370353438.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353439.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353440.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353441.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353442.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353443.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353444.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353445.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353446.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353447.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353448.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353449.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353450.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353451.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353452.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353453.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353454.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353455.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353456.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353457.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353458.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353459.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353460.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353461.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353462.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353463.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353464.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353465.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353466.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353467.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353468.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353469.jpg',
#      'typeId': 2},
#     {'url': 'https://d.inmofactory.com/1/103494/27124517/370353470.jpg',
#      'typeId': 2},
#     {'url': 'https://player.vimeo.com/video/512859475', 'typeId': 21},
#     {'url': 'https://youtu.be/LzokkQMAOus', 'typeId': 21}],
#    'features': [{'key': 'bathrooms',
#      'value': [3],
#      'minValue': 0,
#      'maxValue': 0},
#     {'key': 'conservationState', 'value': [3], 'minValue': 0, 'maxValue': 0},
#     {'key': 'floor', 'value': [6], 'minValue': 0, 'maxValue': 0},
#     {'key': 'elevator', 'value': [1], 'minValue': 0, 'maxValue': 0},
#     {'key': 'rooms', 'value': [4], 'minValue': 0, 'maxValue': 0},
#     {'key': 'surface', 'value': [220], 'minValue': 0, 'maxValue': 0}],
#    'otherFeatures': None,
#    'transactions': [{'transactionTypeId': 3,
#      'value': [2500],
#      'reduced': 0,
#      'periodicityId': 3,
#      'maxPrice': 0,
#      'minPrice': 0}],
#    'products': [],
#    'address': {'ubication': "Calle de O'donnell, Salamanca",
#     'location': {'country': 'España',
#      'level1': 'Madrid',
#      'level2': 'Madrid',
#      'level3': 'Madrid, Zona de',
#      'level4': '',
#      'level5': ' Madrid Capital',
#      'level6': '',
#      'level7': 'Salamanca',
#      'level8': 'Goya',
#      'upperLevel': 'Goya',
#      'countryId': 724,
#      'level1Id': 14,
#      'level2Id': 28,
#      'level3Id': 173,
#      'level4Id': 0,
#      'level5Id': 28079,
#      'level6Id': 0,
#      'level7Id': 667,
#      'level8Id': 18},
#     'coordinates': {'accuracy': 0,
#      'latitude': 40.42152,
#      'longitude': -3.674654},
#     'zipCode': '28009',
#     'customZone': None},
#    'date': '2021-02-19T08:47:41.857Z',
#    'description': 'La vivienda consta de\xa0220m², distribuida en salón-comedor\xa0muy amplio, con grandes\xa0ventanales\xa0en esquina por todo el salón\xa0que le confiere\xa0gran\xa0luminosidad. Cuatro\xa0dormitorios, la habitación principal\xa0con baño en suite,\xa0grandes y amplios\xa0armarios\xa0con mucho espacio de almacenaje y luminosos ventanales.\xa0Las otras dos habitaciones, también exteriores,\xa0con amplios ventanales y mucha luz,\xa0comparten un baño\xa0completo\xa0con plato de ducha.\xa0La cocina, muy amplia y con mucho\xa0espacio, está\xa0totalmente reformada,\xa0da acceso a la habitación y baño de servicio, así como a otra puerta de servicio.\xa0La zona dispone de\xa0una\xa0gran oferta comercial,\xa0se encuentra\xa0a cuatro calles de la Calle\xa0Menéndez\xa0Pelayo\xa0con una gran propuesta gastronómica, varios hospitales,\xa0colegios, supermercados.\xa0El acceso al\xa0transporte\xa0público\xa0es fácil, a tan sólo tres calles del metro Goya, Príncipe de Vergara, Ibiza y O´Donnell y varias líneas de autobús, así\xa0como un rápido y cómodo acceso a la M30.\xa0\r\n',
#    'isTop': False,
#    'isPhotoReport': False,
#    'isMsAdvance': False,
#    'promotionTypeId': 0,
#    'promotionUrl': None,
#    'isExternalContact': False,
#    'isVirtualTour': False}],
#  'adjacentRealEstates': []}

# %%
data = resp.json()

# %%
data.keys()
# Out:
# dict_keys(['breadcrumb', 'count', 'hrefLang', 'client', 'realEstates', 'adjacentRealEstates'])

# %%
df = pd.json_normalize(data['realEstates'])

# %%
pd.json_normalize(df['features'][0]).T
# Out:
#                   0                  1      2      3        4
# key       bathrooms  conservationState  floor  rooms  surface
# value           [1]                [2]    [9]    [2]     [80]
# minValue          0                  0      0      0        0
# maxValue          0                  0      0      0        0

# %%
df['features']
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
pd.json_normalize(df['transactions'][0]).T
# Out:
#                         0
# transactionTypeId       3
# value              [1100]
# reduced                 0
# periodicityId           3
# maxPrice                0
# minPrice                0

# %%
def get_df():
    url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
    response = r.get(url, headers=headers)
    data = response.json()
    df2 = pd.json_normalize(data['realEstates])
    number_of_iteration=0
    time.sleep(22)                             
    for i in range(2,79):
        number_of_iteration+=1
        url = f'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber={i}&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
        response = r.get(url, headers=headers
        data = response.json()
        df2 = df2.append(pd.json_normalize(data['realEstates']))
        if number_of_iteration%10 and number_of_iteration:
            time.sleep(5)
        time.spleep(2)
    return df
# Out:
#   File "<ipython-input-38-8f756bdb6355>", line 5
#     df2 = pd.json_normalize(data['realEstates])
#                                                ^
# SyntaxError: EOL while scanning string literal

# %%
def get_df():
    url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
    resp = r.get(url, headers=headers)
    data = resp.json()
    df = pd.json_normalize(data['realEstates'])
    number_of_iteration=0
    time.sleep(2)
    for i in range(2,3):
        number_of_iteration+=1
        url = f'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber={i}&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
        resp = r.get(url, headers=headers)
        data = resp.json()
        df = df.append(pd.json_normalize(data['realEstates']))
        if number_of_iteration%10 and number_of_iteration:
            time.sleep(5)
        time.sleep(2)
        print(f'Page number: {i} scanned')
    return df

# %%
get_df()
# Out:
# Page number: 2 scanned
#            id  promotionId  typeId  subtypeId  isNew  isPremium  \
# 0   158295767            0       2          1  False       True
# 1   157930000            0       2          1  False       True
# 2   155304126            0       2          7  False       True
# 3   158594524            0       2          1  False       True
# 4   157612297            0       2          1  False       True
# ..        ...          ...     ...        ...    ...        ...
# 25  157682368            0       2          1  False      False
# 26  158952280            0       2          1  False      False
# 27  157669877            0       2          1  False      False
# 28  158953456            0       2          1  False      False
# 29  158858328            0       2          1  False      False
#
#                                           multimedias  \
# 0   [{'url': 'https://d.inmofactory.com/1/110063/2...
# 1   [{'url': 'https://d.inmofactory.com/1/86845/26...
# 2   [{'url': 'https://d.inmofactory.com/1/118683/1...
# 3   [{'url': 'https://d.inmofactory.com/1/118683/2...
# 4   [{'url': 'https://d.inmofactory.com/1/86845/22...
# ..                                                ...
# 25  [{'url': 'https://my.matterport.com/show/?m=do...
# 26  [{'url': 'https://d.inmofactory.com/1/114585/2...
# 27  [{'url': 'https://my.matterport.com/show/?m=TS...
# 28  [{'url': 'https://my.matterport.com/show/?m=tX...
# 29  [{'url': 'https://d.inmofactory.com/1/107701/2...
#
#                                              features otherFeatures  \
# 0   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 1   [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 2   [{'key': 'bathrooms', 'value': [4], 'minValue'...          None
# 3   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 4   [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# ..                                                ...           ...
# 25  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 26  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 27  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 28  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 29  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
#
#                                          transactions  ...  \
# 0   [{'transactionTypeId': 3, 'value': [780], 'red...  ...
# 1   [{'transactionTypeId': 3, 'value': [1400], 're...  ...
# 2   [{'transactionTypeId': 3, 'value': [4500], 're...  ...
# 3   [{'transactionTypeId': 3, 'value': [980], 'red...  ...
# 4   [{'transactionTypeId': 3, 'value': [1400], 're...  ...
# ..                                                ...  ...
# 25  [{'transactionTypeId': 3, 'value': [1000], 're...  ...
# 26  [{'transactionTypeId': 3, 'value': [1800], 're...  ...
# 27  [{'transactionTypeId': 3, 'value': [875], 'red...  ...
# 28  [{'transactionTypeId': 3, 'value': [1050], 're...  ...
# 29  [{'transactionTypeId': 3, 'value': [1250], 're...  ...
#
#    address.location.level5Id address.location.level6Id  \
# 0                      28079                         0
# 1                      28079                         0
# 2                      28079                         0
# 3                      28079                         0
# 4                      28079                         0
# ..                       ...                       ...
# 25                     28079                         0
# 26                     28079                         0
# 27                     28079                         0
# 28                     28079                         0
# 29                     28079                         0
#
#    address.location.level7Id  address.location.level8Id  \
# 0                        680                        104
# 1                        199                        122
# 2                        678                         90
# 3                        678                         90
# 4                        199                        122
# ..                       ...                        ...
# 25                       176                        113
# 26                       177                        141
# 27                       681                        106
# 28                       176                        115
# 29                       685                        131
#
#     address.coordinates.accuracy  address.coordinates.latitude  \
# 0                              0                      40.36052
# 1                              0                      40.41872
# 2                              0                      40.45386
# 3                              0                      40.46057
# 4                              1                      40.41804
# ..                           ...                           ...
# 25                             0                      40.44626
# 26                             0                      40.43587
# 27                             0                      40.46430
# 28                             0                      40.45585
# 29                             0                      40.47562
#
#     address.coordinates.longitude address.zipCode  address.customZone  \
# 0                       -3.594352           28051                None
# 1                       -3.671893           28009                None
# 2                       -3.641407           28043                None
# 3                       -3.637343           28043                None
# 4                       -3.674870           28009                None
# ..                            ...             ...                 ...
# 25                      -3.675571           28002                None
# 26                      -3.701106           28010                None
# 27                      -3.704240           28039                None
# 28                      -3.680258           28016                None
# 29                      -3.671450           28033                None
#
#     advertiser.logo
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
#
# [68 rows x 55 columns]

# %%
def get_df():
    url = 'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber=1&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
    resp = r.get(url, headers=headers)
    data = resp.json()
    df = pd.json_normalize(data['realEstates'])
    number_of_iteration=0
    time.sleep(2)
    for i in range(2,3):
        number_of_iteration+=1
        url = f'https://api.fotocasa.es/PropertySearch/Search?combinedLocationIds=724,14,28,173,0,28079,0,0,0&culture=es-ES&featureIds=130&hrefLangCultures=ca-ES%3Bes-ES%3Bde-DE%3Ben-GB&isMap=false&isNewConstruction=false&isNewConstructionPromotions=false&latitude=40.4096&longitude=-3.68624&pageNumber={i}&platformId=1&sortOrderDesc=true&sortType=bumpdate&transactionTypeId=3&propertyTypeId=2'
        resp = r.get(url, headers=headers)
        data = resp.json()
        df = df.append(pd.json_normalize(data['realEstates']))
        if number_of_iteration%10 and number_of_iteration:
            time.sleep(5)
        time.sleep(2)
        print(f'Page number: {i} scanned')
    return df

# %%
df
# Out:
#            id  promotionId  typeId  subtypeId  isNew  isPremium  \
# 0   158979649            0       2          1   True      False
# 1   157856441            0       2          1  False      False
# 2   158321485            0       2          1  False      False
# 3   158979205            0       2          1   True      False
# 4   154313630            0       2          3  False      False
# 5   158978440            0       2          1   True      False
# 6   158978581            0       2          1   True      False
# 7   156529977            0       2          1  False      False
# 8   158839013            0       2          1  False      False
# 9   156286085            0       2          2  False      False
# 10  158978423            0       2          1   True      False
# 11  158113487            0       2          1  False      False
# 12  158638517            0       2          1  False      False
# 13  155661855            0       2          1  False      False
# 14  156399316            0       2          1  False      False
# 15  158632550            0       2          1  False      False
# 16  155662003            0       2          1  False      False
# 17  155661826            0       2          1  False      False
# 18  158102356            0       2          1  False      False
# 19  158971298            0       2          1   True      False
# 20  155661933            0       2          1  False      False
# 21  155661831            0       2          1  False      False
# 22  158970657            0       2          1   True      False
# 23  158957129            0       2          1  False      False
# 24  158965215            0       2          1  False      False
# 25  158957575            0       2          1  False      False
# 26  158957433            0       2          1  False      False
# 27  158956587            0       2          7  False      False
# 28  158936541            0       2          1  False      False
# 29  158935954            0       2          1  False      False
#
#                                           multimedias  \
# 0   [{'url': 'https://d.inmofactory.com/1/111635/2...
# 1   [{'url': 'https://d.inmofactory.com/1/114585/2...
# 2   [{'url': 'https://my.matterport.com/show/?m=W8...
# 3   [{'url': 'https://d.inmofactory.com/1/125783/2...
# 4   [{'url': 'https://d.inmofactory.com/1/114670/1...
# 5   [{'url': 'https://d.inmofactory.com/1/97321/71...
# 6   [{'url': 'https://d.inmofactory.com/1/103494/2...
# 7   [{'url': 'https://d.inmofactory.com/1/97321/87...
# 8   [{'url': 'https://d.inmofactory.com/1/97321/27...
# 9   [{'url': 'https://d.inmofactory.com/1/97321/11...
# 10  [{'url': 'https://d.inmofactory.com/1/86714/27...
# 11  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 12  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 13  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 14  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 15  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 16  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 17  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 18  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 19  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 20  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 21  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 22  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 23  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 24  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 25  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 26  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 27  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 28  [{'url': 'https://d.inmofactory.com/1/103494/2...
# 29  [{'url': 'https://d.inmofactory.com/1/103494/2...
#
#                                              features otherFeatures  \
# 0   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 1   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 2   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 3   [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 4   [{'key': 'bathrooms', 'value': [4], 'minValue'...          None
# 5   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 6   [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 7   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 8   [{'key': 'conservationState', 'value': [1], 'm...          None
# 9   [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 10  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 11  [{'key': 'bathrooms', 'value': [3], 'minValue'...          None
# 12  [{'key': 'bathrooms', 'value': [4], 'minValue'...          None
# 13  [{'key': 'bathrooms', 'value': [3], 'minValue'...          None
# 14  [{'key': 'bathrooms', 'value': [5], 'minValue'...          None
# 15  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 16  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 17  [{'key': 'bathrooms', 'value': [4], 'minValue'...          None
# 18  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 19  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 20  [{'key': 'bathrooms', 'value': [4], 'minValue'...          None
# 21  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 22  [{'key': 'bathrooms', 'value': [5], 'minValue'...          None
# 23  [{'key': 'bathrooms', 'value': [1], 'minValue'...          None
# 24  [{'key': 'bathrooms', 'value': [4], 'minValue'...          None
# 25  [{'key': 'bathrooms', 'value': [3], 'minValue'...          None
# 26  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 27  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 28  [{'key': 'bathrooms', 'value': [2], 'minValue'...          None
# 29  [{'key': 'bathrooms', 'value': [3], 'minValue'...          None
#
#                                          transactions  ...  \
# 0   [{'transactionTypeId': 3, 'value': [1100], 're...  ...
# 1   [{'transactionTypeId': 3, 'value': [700], 'red...  ...
# 2   [{'transactionTypeId': 3, 'value': [800], 'red...  ...
# 3   [{'transactionTypeId': 3, 'value': [1600], 're...  ...
# 4   [{'transactionTypeId': 3, 'value': [3500], 're...  ...
# 5   [{'transactionTypeId': 3, 'value': [1000], 're...  ...
# 6   [{'transactionTypeId': 3, 'value': [1390], 're...  ...
# 7   [{'transactionTypeId': 3, 'value': [1600], 're...  ...
# 8   [{'transactionTypeId': 3, 'value': [1000], 're...  ...
# 9   [{'transactionTypeId': 3, 'value': [700], 'red...  ...
# 10  [{'transactionTypeId': 3, 'value': [770], 'red...  ...
# 11  [{'transactionTypeId': 3, 'value': [6000], 're...  ...
# 12  [{'transactionTypeId': 3, 'value': [3900], 're...  ...
# 13  [{'transactionTypeId': 3, 'value': [2400], 're...  ...
# 14  [{'transactionTypeId': 3, 'value': [6000], 're...  ...
# 15  [{'transactionTypeId': 3, 'value': [900], 'red...  ...
# 16  [{'transactionTypeId': 3, 'value': [1200], 're...  ...
# 17  [{'transactionTypeId': 3, 'value': [5500], 're...  ...
# 18  [{'transactionTypeId': 3, 'value': [2100], 're...  ...
# 19  [{'transactionTypeId': 3, 'value': [1250], 're...  ...
# 20  [{'transactionTypeId': 3, 'value': [5500], 're...  ...
# 21  [{'transactionTypeId': 3, 'value': [5000], 're...  ...
# 22  [{'transactionTypeId': 3, 'value': [4200], 're...  ...
# 23  [{'transactionTypeId': 3, 'value': [1400], 're...  ...
# 24  [{'transactionTypeId': 3, 'value': [5200], 're...  ...
# 25  [{'transactionTypeId': 3, 'value': [2950], 're...  ...
# 26  [{'transactionTypeId': 3, 'value': [1500], 're...  ...
# 27  [{'transactionTypeId': 3, 'value': [3800], 're...  ...
# 28  [{'transactionTypeId': 3, 'value': [1550], 're...  ...
# 29  [{'transactionTypeId': 3, 'value': [2500], 're...  ...
#
#    address.location.level5Id address.location.level6Id  \
# 0                      28079                         0
# 1                      28079                         0
# 2                      28079                         0
# 3                      28079                         0
# 4                      28079                         0
# 5                      28079                         0
# 6                      28079                         0
# 7                      28079                         0
# 8                      28079                         0
# 9                      28079                         0
# 10                     28079                         0
# 11                     28079                         0
# 12                     28079                         0
# 13                     28079                         0
# 14                     28079                         0
# 15                     28079                         0
# 16                     28079                         0
# 17                     28079                         0
# 18                     28079                         0
# 19                     28079                         0
# 20                     28079                         0
# 21                     28079                         0
# 22                     28079                         0
# 23                     28079                         0
# 24                     28079                         0
# 25                     28079                         0
# 26                     28079                         0
# 27                     28079                         0
# 28                     28079                         0
# 29                     28079                         0
#
#    address.location.level7Id  address.location.level8Id  \
# 0                        672                         50
# 1                        672                         50
# 2                        671                         44
# 3                        177                        139
# 4                        678                         88
# 5                        176                        113
# 6                        199                        122
# 7                        667                         17
# 8                        672                         46
# 9                        672                         46
# 10                       670                         35
# 11                       667                         17
# 12                       667                         17
# 13                       667                         19
# 14                       667                         17
# 15                       678                         93
# 16                       681                        110
# 17                       667                         18
# 18                       672                         49
# 19                       681                        107
# 20                       667                         17
# 21                       667                         17
# 22                       669                         28
# 23                       672                         49
# 24                       667                         17
# 25                       176                        115
# 26                       176                        115
# 27                       672                         46
# 28                       177                        138
# 29                       667                         18
#
#     address.coordinates.accuracy  address.coordinates.latitude  \
# 0                              0                      40.42612
# 1                              0                      40.42575
# 2                              0                      40.39276
# 3                              0                      40.43119
# 4                              0                      40.45240
# 5                              1                      40.44811
# 6                              1                      40.41640
# 7                              1                      40.42205
# 8                              1                      40.42851
# 9                              1                      40.42851
# 10                             0                      40.34374
# 11                             0                      40.42699
# 12                             0                      40.42825
# 13                             0                      40.43650
# 14                             0                      40.42704
# 15                             0                      40.48494
# 16                             0                      40.45643
# 17                             0                      40.42702
# 18                             0                      40.41544
# 19                             0                      40.45430
# 20                             0                      40.42560
# 21                             0                      40.42250
# 22                             0                      40.47239
# 23                             0                      40.41587
# 24                             0                      40.42585
# 25                             0                      40.45650
# 26                             0                      40.45830
# 27                             1                      40.42410
# 28                             0                      40.43696
# 29                             0                      40.42152
#
#     address.coordinates.longitude address.zipCode  address.customZone  \
# 0                       -3.708903           28015                None
# 1                       -3.703881           28004                None
# 2                       -3.694824           28045                None
# 3                       -3.693810           28010                None
# 4                       -3.609116           28042                None
# 5                       -3.672590           28002                None
# 6                       -3.674980           28009                None
# 7                       -3.686920           28001                None
# 8                       -3.701390           28004                None
# 9                       -3.701390           28004                None
# 10                      -3.685089           28021                None
# 11                      -3.682479           28001                None
# 12                      -3.686216           28001                None
# 13                      -3.680711           28006                None
# 14                      -3.687013           28001                None
# 15                      -3.666906           28050                None
# 16                      -3.696257           28020                None
# 17                      -3.679696           28001                None
# 18                      -3.710526           41003                None
# 19                      -3.692779           28020                None
# 20                      -3.687048           28001                None
# 21                      -3.680875           28009                None
# 22                      -3.785722           28023                None
# 23                      -3.711101           28013                None
# 24                      -3.688947           28001                None
# 25                      -3.688547           28036                None
# 26                      -3.686574           28036                None
# 27                      -3.697160           28004                None
# 28                      -3.710246           28015                None
# 29                      -3.674654           28009                None
#
#     advertiser.logo
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
#
# [30 rows x 55 columns]
